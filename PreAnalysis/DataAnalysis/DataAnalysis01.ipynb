# %% [markdown]
# # First Data AnalysisProcess
#
# In this notebook file FabricWaste DataFrame will be merged with related DataFrames and saved as pkl file for Data Analysis prcesses

# %%
#Library is being imported
import pandas as pd

# %%
#Library version is being printed
print('pandas Version: ' + pd.__version__)
# Out:
# pandas Version: 1.5.2

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/FinalPreparation/FabricWaste.pkl")
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0            4          35              3            375    0.064198
# 1            4          65              3            375    0.060386
# 2            4          65              3            375    0.077121
# 3            4          65              3            375    0.062802
# 4            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality
# 0           0.014815      25              6
# 1           0.007246      23              3
# 2           0.028278      29             11
# 3           0.019324      24              8
# 4           0.007246      18              3

# %%
#colorFrame is being created from pkl file
colorFrame = pd.read_pickle("../Data/WithRelationalTables/Color.pkl")
colorFrame.head()
# Out:
#               Color        ColorCode ColorType   ColorTypeName  \
# 0   AOP BLUMENWIESE     [-1, -1, -1]       AOP  All Over Print
# 1  AOP UNTER WASSER     [-1, -1, -1]       AOP  All Over Print
# 2         AUBERGINE     [72, 50, 72]        SC     Solid Color
# 3          BLASGELB  [255, 255, 167]        SC     Solid Color
# 4          BLAUGRAU   [106, 90, 205]        SC     Solid Color
#
#   CustomerDefinedCategory
# 0              MixedColor
# 1              MixedColor
# 2                 Pinkish
# 3               Yellowish
# 4                DarkBlue

# %%
#For each row in the dataFrame, the data in the colorFrame is being added to dataFrame
#This operation is being done by merging dataFrame and colorFrame on ColorID
dataFrame = pd.merge(dataFrame, colorFrame, left_on = 'ColorID', right_index = True, how = 'left')
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0            4          35              3            375    0.064198
# 1            4          65              3            375    0.060386
# 2            4          65              3            375    0.077121
# 3            4          65              3            375    0.062802
# 4            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality       Color        ColorCode  \
# 0           0.014815      25              6       PINIE     [42, 47, 35]
# 1           0.007246      23              3    PFIRSICH  [255, 229, 180]
# 2           0.028278      29             11    HELLBLAU  [173, 216, 230]
# 3           0.019324      24              8  PETROLBLAU     [0, 95, 106]
# 4           0.007246      18              3   AUBERGINE     [72, 50, 72]
#
#   ColorType ColorTypeName CustomerDefinedCategory
# 0        SC   Solid Color                Greenish
# 1        SC   Solid Color               Orangeish
# 2        SC   Solid Color                  Bluish
# 3        SC   Solid Color                  Bluish
# 4        SC   Solid Color                 Pinkish

# %%
#Color and ColorTypeName columns that saved for informational purposes are being removed from dataFrame
dataFrame.drop(['Color', 'ColorTypeName'], axis = 1, inplace = True)
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0            4          35              3            375    0.064198
# 1            4          65              3            375    0.060386
# 2            4          65              3            375    0.077121
# 3            4          65              3            375    0.062802
# 4            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality        ColorCode ColorType  \
# 0           0.014815      25              6     [42, 47, 35]        SC
# 1           0.007246      23              3  [255, 229, 180]        SC
# 2           0.028278      29             11  [173, 216, 230]        SC
# 3           0.019324      24              8     [0, 95, 106]        SC
# 4           0.007246      18              3     [72, 50, 72]        SC
#
#   CustomerDefinedCategory
# 0                Greenish
# 1               Orangeish
# 2                  Bluish
# 3                  Bluish
# 4                 Pinkish

# %%
#Since ColorCode is a detailed feature, it will not be used within the scope of PreAnalysis
#ColorCode column is being removed from dataFrame
dataFrame.drop('ColorCode', axis = 1, inplace = True)
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0            4          35              3            375    0.064198
# 1            4          65              3            375    0.060386
# 2            4          65              3            375    0.077121
# 3            4          65              3            375    0.062802
# 4            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality ColorType CustomerDefinedCategory
# 0           0.014815      25              6        SC                Greenish
# 1           0.007246      23              3        SC               Orangeish
# 2           0.028278      29             11        SC                  Bluish
# 3           0.019324      24              8        SC                  Bluish
# 4           0.007246      18              3        SC                 Pinkish

# %%
#productDetailFrame is being created from pkl file
productDetailFrame = pd.read_pickle("../Data/WithRelationalTables/ProductDetail.pkl")
productDetailFrame.head()
# Out:
#             ProductDetail Maturity  Gender ProductType ProductTypeCategory
# 0           KADIN T-SHIRT    Adult  Female     T-Shirt                 Top
# 1          KADIN PANTOLON    Adult  Female        Pant                 Leg
# 2            KADIN GOMLEK    Adult  Female       Shirt                 Top
# 3            KADIN ELBISE    Adult  Female       Dress                Full
# 4  ERKEK PIJAMA / GECELIK    Adult    Male     Pyjamas                Full

# %%
#For each row in the dataFrame, the data in the productDetailFrame is being added to dataFrame
#This operation is being done by merging dataFrame and productDetailFrame on ProductDetailID
dataFrame = pd.merge(dataFrame, productDetailFrame, left_on = 'ProductDetailID', right_index = True, how = 'left')
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  ...  \
# 0            4          35              3            375  ...
# 1            4          65              3            375  ...
# 2            4          65              3            375  ...
# 3            4          65              3            375  ...
# 4            4          65              3            375  ...
#
#    SecondQualityRate  Defect  SecondQuality  ColorType  \
# 0           0.014815      25              6         SC
# 1           0.007246      23              3         SC
# 2           0.028278      29             11         SC
# 3           0.019324      24              8         SC
# 4           0.007246      18              3         SC
#
#   CustomerDefinedCategory  ProductDetail Maturity  Gender ProductType  \
# 0                Greenish  KADIN T-SHIRT    Adult  Female     T-Shirt
# 1               Orangeish  KADIN T-SHIRT    Adult  Female     T-Shirt
# 2                  Bluish  KADIN T-SHIRT    Adult  Female     T-Shirt
# 3                  Bluish  KADIN T-SHIRT    Adult  Female     T-Shirt
# 4                 Pinkish  KADIN T-SHIRT    Adult  Female     T-Shirt
#
#   ProductTypeCategory
# 0                 Top
# 1                 Top
# 2                 Top
# 3                 Top
# 4                 Top
#
# [5 rows x 21 columns]

# %%
#ProductDetail column that saved for informational purposes is being removed from dataFrame
dataFrame.drop('ProductDetail', axis = 1, inplace = True)
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0            4          35              3            375    0.064198
# 1            4          65              3            375    0.060386
# 2            4          65              3            375    0.077121
# 3            4          65              3            375    0.062802
# 4            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality ColorType CustomerDefinedCategory  \
# 0           0.014815      25              6        SC                Greenish
# 1           0.007246      23              3        SC               Orangeish
# 2           0.028278      29             11        SC                  Bluish
# 3           0.019324      24              8        SC                  Bluish
# 4           0.007246      18              3        SC                 Pinkish
#
#   Maturity  Gender ProductType ProductTypeCategory
# 0    Adult  Female     T-Shirt                 Top
# 1    Adult  Female     T-Shirt                 Top
# 2    Adult  Female     T-Shirt                 Top
# 3    Adult  Female     T-Shirt                 Top
# 4    Adult  Female     T-Shirt                 Top

# %%
#fabricDetailFrame is being created from pkl file
fabricDetailFrame = pd.read_pickle("../Data/WithRelationalTables/FabricDetail.pkl")
fabricDetailFrame.head()
# Out:
#   FabricCode                                       FabricDetail     FabricType
# 0     2IN007  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....      Interlock
# 1     2RB201  NE 30/1 PNY RAPORLU - RIBANA A.EN 34 20 E 175 ...         Ribana
# 2     2SP021  NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...  Single Jersey
# 3     2SP033  NE 20/1 PNY - SUPREM A.EN 32 22 190 G/M2 %100 ...  Single Jersey
# 4     2SP050  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey

# %%
#For each row in the dataFrame, the data in the fabricDetailFrame is being added to dataFrame
#This operation is being done by merging dataFrame and fabricDetailFrame on FabricCode
dataFrame = dataFrame.merge(fabricDetailFrame, on = 'FabricCode', how = 'left')
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  ...  Defect  \
# 0            4          35              3            375  ...      25
# 1            4          65              3            375  ...      23
# 2            4          65              3            375  ...      29
# 3            4          65              3            375  ...      24
# 4            4          65              3            375  ...      18
#
#    SecondQuality  ColorType  CustomerDefinedCategory Maturity  Gender  \
# 0              6         SC                 Greenish    Adult  Female
# 1              3         SC                Orangeish    Adult  Female
# 2             11         SC                   Bluish    Adult  Female
# 3              8         SC                   Bluish    Adult  Female
# 4              3         SC                  Pinkish    Adult  Female
#
#   ProductType ProductTypeCategory  \
# 0     T-Shirt                 Top
# 1     T-Shirt                 Top
# 2     T-Shirt                 Top
# 3     T-Shirt                 Top
# 4     T-Shirt                 Top
#
#                                         FabricDetail     FabricType
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...  Single Jersey
#
# [5 rows x 22 columns]

# %%
#FabricDetail column that saved for informational purposes is being removed from dataFrame
dataFrame.drop('FabricDetail', axis = 1, inplace = True)
dataFrame.head()
# Out:
#    ColorID  ProductDetailID FabricCode  IsManualProcess  Weight  Width  \
# 0       18                0     2SP050            False     125    150
# 1       19                0     2SP050            False     125    150
# 2        6                0     2SP050            False     125    150
# 3       20                0     2SP050            False     125    150
# 4        2                0     2SP050            False     125    150
#
#    ProductPart  NotchLayer  NotchQuantity  OrderQuantity  ...  \
# 0            4          35              3            375  ...
# 1            4          65              3            375  ...
# 2            4          65              3            375  ...
# 3            4          65              3            375  ...
# 4            4          65              3            375  ...
#
#    SecondQualityRate  Defect  SecondQuality  ColorType  \
# 0           0.014815      25              6         SC
# 1           0.007246      23              3         SC
# 2           0.028278      29             11         SC
# 3           0.019324      24              8         SC
# 4           0.007246      18              3         SC
#
#   CustomerDefinedCategory Maturity  Gender ProductType ProductTypeCategory  \
# 0                Greenish    Adult  Female     T-Shirt                 Top
# 1               Orangeish    Adult  Female     T-Shirt                 Top
# 2                  Bluish    Adult  Female     T-Shirt                 Top
# 3                  Bluish    Adult  Female     T-Shirt                 Top
# 4                 Pinkish    Adult  Female     T-Shirt                 Top
#
#       FabricType
# 0  Single Jersey
# 1  Single Jersey
# 2  Single Jersey
# 3  Single Jersey
# 4  Single Jersey
#
# [5 rows x 21 columns]

# %%
#ColorID and ProductDetailID columns that only used to relate colorFrame and productDetailFrame to dataFrame are being removed
#Since FabricCode column can also be used as categorical data, it will not be removed
dataFrame.drop(['ColorID', 'ProductDetailID'], axis = 1, inplace = True)
dataFrame.head()
# Out:
#   FabricCode  IsManualProcess  Weight  Width  ProductPart  NotchLayer  \
# 0     2SP050            False     125    150            4          35
# 1     2SP050            False     125    150            4          65
# 2     2SP050            False     125    150            4          65
# 3     2SP050            False     125    150            4          65
# 4     2SP050            False     125    150            4          65
#
#    NotchQuantity  OrderQuantity  DefectRate  SecondQualityRate  Defect  \
# 0              3            375    0.064198           0.014815      25
# 1              3            375    0.060386           0.007246      23
# 2              3            375    0.077121           0.028278      29
# 3              3            375    0.062802           0.019324      24
# 4              3            375    0.045894           0.007246      18
#
#    SecondQuality ColorType CustomerDefinedCategory Maturity  Gender  \
# 0              6        SC                Greenish    Adult  Female
# 1              3        SC               Orangeish    Adult  Female
# 2             11        SC                  Bluish    Adult  Female
# 3              8        SC                  Bluish    Adult  Female
# 4              3        SC                 Pinkish    Adult  Female
#
#   ProductType ProductTypeCategory     FabricType
# 0     T-Shirt                 Top  Single Jersey
# 1     T-Shirt                 Top  Single Jersey
# 2     T-Shirt                 Top  Single Jersey
# 3     T-Shirt                 Top  Single Jersey
# 4     T-Shirt                 Top  Single Jersey

# %%
#dataFrame columns are being reordered in CategoricalInput/ContinuousInput/Output format
newColumnOrder = dataFrame.columns.tolist()
newColumnOrder = newColumnOrder[12:] + newColumnOrder[:12]
dataFrame = dataFrame[newColumnOrder]
dataFrame.head()
# Out:
#   ColorType CustomerDefinedCategory Maturity  Gender ProductType  \
# 0        SC                Greenish    Adult  Female     T-Shirt
# 1        SC               Orangeish    Adult  Female     T-Shirt
# 2        SC                  Bluish    Adult  Female     T-Shirt
# 3        SC                  Bluish    Adult  Female     T-Shirt
# 4        SC                 Pinkish    Adult  Female     T-Shirt
#
#   ProductTypeCategory     FabricType FabricCode  IsManualProcess  Weight  \
# 0                 Top  Single Jersey     2SP050            False     125
# 1                 Top  Single Jersey     2SP050            False     125
# 2                 Top  Single Jersey     2SP050            False     125
# 3                 Top  Single Jersey     2SP050            False     125
# 4                 Top  Single Jersey     2SP050            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  OrderQuantity  DefectRate  \
# 0    150            4          35              3            375    0.064198
# 1    150            4          65              3            375    0.060386
# 2    150            4          65              3            375    0.077121
# 3    150            4          65              3            375    0.062802
# 4    150            4          65              3            375    0.045894
#
#    SecondQualityRate  Defect  SecondQuality
# 0           0.014815      25              6
# 1           0.007246      23              3
# 2           0.028278      29             11
# 3           0.019324      24              8
# 4           0.007246      18              3

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 185
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ColorType                186 non-null    object
#  1   CustomerDefinedCategory  186 non-null    object
#  2   Maturity                 186 non-null    object
#  3   Gender                   186 non-null    object
#  4   ProductType              186 non-null    object
#  5   ProductTypeCategory      186 non-null    object
#  6   FabricType               186 non-null    object
#  7   FabricCode               186 non-null    object
#  8   IsManualProcess          186 non-null    bool
#  9   Weight                   186 non-null    int64
#  10  Width                    186 non-null    int64
#  11  ProductPart              186 non-null    int64
#  12  NotchLayer               186 non-null    int64
#  13  NotchQuantity            186 non-null    int64
#  14  OrderQuantity            186 non-null    int64
#  15  DefectRate               186 non-null    float64
#  16  SecondQualityRate        186 non-null    float64
#  17  Defect                   186 non-null    int64
#  18  SecondQuality            186 non-null    int64
# dtypes: bool(1), float64(2), int64(8), object(8)
# memory usage: 27.8+ KB

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  186.000000  186.000000   186.000000  186.000000     186.000000
# mean   165.241935  159.435484     4.801075   44.483871       2.467742
# std     36.999935   15.936653     2.289388   21.042615       0.792896
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   31.000000       2.000000
# 50%    172.500000  160.000000     4.000000   39.000000       3.000000
# 75%    190.000000  171.500000     5.000000   58.000000       3.000000
# max    250.000000  180.000000    14.000000  111.000000       4.000000
#
#        OrderQuantity  DefectRate  SecondQualityRate      Defect  SecondQuality
# count     186.000000  186.000000         186.000000  186.000000     186.000000
# mean      294.489247    0.047758           0.026811   13.908602       7.919355
# std       113.160409    0.028010           0.023099    8.328864       6.445527
# min       100.000000    0.000000           0.000000    0.000000       0.000000
# 25%       206.250000    0.028916           0.011349    8.000000       4.000000
# 50%       250.000000    0.041523           0.020425   12.000000       6.000000
# 75%       380.000000    0.062802           0.035610   17.750000      10.000000
# max       640.000000    0.165803           0.165803   60.000000      42.000000

# %%
#dataFrame is being saved as pkl files
dataFrame.to_pickle("../Data/DataAnalysis/FabricWaste.pkl")
