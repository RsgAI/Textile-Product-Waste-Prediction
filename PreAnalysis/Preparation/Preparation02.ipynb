# %% [markdown]
# # Second Data Preparation Process
#
# In this notebook file, the dataset provided by the customer will be eddited for general purposes.
#
# Features will be examined a little more deeply by focusing in particular on the data types of them.

# %%
#Libraries are being imported
import numpy as np
import pandas as pd

# %%
#Library versions are being printed
print('numpy Version: ' + np.__version__)
print('pandas Version: ' + pd.__version__)
# Out:
# numpy Version: 1.23.5
# pandas Version: 1.5.2

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/NeddedColumns/FabricWaste.pkl")
dataFrame.head()
# Out:
#                       Product        Color  ProductDetail FabricCode  \
# 0  M6030 JERSEY SHIRT LANGARM        PINIE  KADIN T-SHIRT     2SP050
# 1  M6030 JERSEY SHIRT LANGARM     PFIRSICH  KADIN T-SHIRT     2SP050
# 2  M6030 JERSEY SHIRT LANGARM     HELLBLAU  KADIN T-SHIRT     2SP050
# 3  M6030 JERSEY SHIRT LANGARM   PETROLBLAU  KADIN T-SHIRT     2SP050
# 4  M6030 JERSEY SHIRT LANGARM  AUBERGINE 2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  Weight Width  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
#
#    ProductPart NotchLayer NotchQuantity  OrderQuantity  Quantity  Repair  \
# 0            4         35             3            375       405      20
# 1            4         65             3            375       414      22
# 2            4         65             3            375       389      19
# 3            4         65             3            375       414      18
# 4            4         65             3            375       414      16
#
#    Delivery  SecondQuality
# 0       399              6
# 1       411              3
# 2       378             11
# 3       406              8
# 4       411              3

# %%
#Information of dataFrame is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        186 non-null    object
#  1   Color          186 non-null    object
#  2   ProductDetail  186 non-null    object
#  3   FabricCode     186 non-null    object
#  4   FabricDetail   186 non-null    object
#  5   Weight         186 non-null    int64
#  6   Width          186 non-null    object
#  7   ProductPart    186 non-null    int64
#  8   NotchLayer     186 non-null    object
#  9   NotchQuantity  178 non-null    object
#  10  OrderQuantity  186 non-null    int64
#  11  Quantity       186 non-null    int64
#  12  Repair         186 non-null    int64
#  13  Delivery       186 non-null    int64
#  14  SecondQuality  186 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 21.9+ KB

# %%
#Statistical information of dataFrame is being printed
dataFrame.describe()
# Out:
#            Weight  ProductPart  OrderQuantity    Quantity      Repair  \
# count  186.000000   186.000000     186.000000  186.000000  186.000000
# mean   165.241935     4.801075     294.489247  317.209677    6.387097
# std     36.999935     2.289388     113.160409  123.932912    4.987622
# min    125.000000     2.000000     100.000000  110.000000    0.000000
# 25%    125.000000     4.000000     206.250000  224.000000    3.000000
# 50%    172.500000     4.000000     250.000000  272.000000    6.000000
# 75%    190.000000     5.000000     380.000000  414.000000    8.000000
# max    250.000000    14.000000     640.000000  698.000000   30.000000
#
#          Delivery  SecondQuality
# count  186.000000     186.000000
# mean   309.311828       7.897849
# std    122.498051       6.454439
# min    112.000000      -2.000000
# 25%    217.000000       4.000000
# 50%    265.000000       6.000000
# 75%    407.500000      10.000000
# max    690.000000      38.000000

# %%
#The Product column is a string type attribute that contains the name of the product to be produced
#This attribute can be used as categorical data in its raw form or detailed information can be collected by processing it
#Since object data type is a good choice for data of this type, no action is required in this section
dataFrame['Product']
# Out:
# 0      M6030 JERSEY SHIRT LANGARM
# 1      M6030 JERSEY SHIRT LANGARM
# 2      M6030 JERSEY SHIRT LANGARM
# 3      M6030 JERSEY SHIRT LANGARM
# 4      M6030 JERSEY SHIRT LANGARM
#                   ...
# 181      M6145 WENDE KAPUZENSHİRT
# 182        M6146 ROCK BLUMENWİESE
# 183      M6151 KURZER SCHLAFANZUG
# 184    M6225 BERMUDA UNTER WASSER
# 185        M6438 JERSEYROCK FLEUR
# Name: Product, Length: 186, dtype: object

# %%
#The Color column is a string type attribute that contains the color information of the product to be produced
#This attribute can be used as categorical data in its raw form or can be categorized for consideration in a broader context
#Since object data type is a good choice for data of this type, no action is required in this section
dataFrame['Color']
# Out:
# 0                 PINIE
# 1              PFIRSICH
# 2              HELLBLAU
# 3            PETROLBLAU
# 4           AUBERGINE 2
#              ...
# 181    AOP UNTER WASSER
# 182     AOP BLUMENWIESE
# 183          RINGEL AOP
# 184    AOP UNTER WASSER
# 185    WÄSCHE FLEUR AOP
# Name: Color, Length: 186, dtype: object

# %%
#The ProductDetail column is a string type attribute that contains the information of the product to be produced
#This attribute can be used as categorical data in its raw form or detailed information can be collected by processing it
#Since object data type is a good choice for data of this type, no action is required in this section
dataFrame['ProductDetail']
# Out:
# 0               KADIN T-SHIRT
# 1               KADIN T-SHIRT
# 2               KADIN T-SHIRT
# 3               KADIN T-SHIRT
# 4               KADIN T-SHIRT
#                 ...
# 181               COCUK SWEAT
# 182        KIZ COCUK PANTOLON
# 183    COCUK PIJAMA / GECELIK
# 184        KIZ COCUK PANTOLON
# 185            KIZ COCUK ETEK
# Name: ProductDetail, Length: 186, dtype: object

# %%
#The FabricCode column is a string type attribute that contains the product code of the fabric to be used
#This attribute can be used as categorical data in its raw form
#Since object data type is a good choice for data of this type, no action is required in this section
dataFrame['FabricCode']
# Out:
# 0      2SP050
# 1      2SP050
# 2      2SP050
# 3      2SP050
# 4      2SP050
#         ...
# 181    2SP309
# 182    2SP309
# 183    2SP021
# 184    2SP021
# 185    2SP309
# Name: FabricCode, Length: 186, dtype: object

# %%
#The FabricDetail column is a string type attribute that contains the detailed information about the fabric to be used
#This attribute can be used by processing the detailed information in it
#Since object data type is a good choice for data of this type, no action is required in this section
dataFrame['FabricDetail']
# Out:
# 0      NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...
# 1      NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...
# 2      NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...
# 3      NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...
# 4      NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...
#                              ...
# 181    NE 30/1 PNY - SUPREM A.EN 32 28 170 G/M2 %100 ...
# 182    NE 30/1 PNY - SUPREM A.EN 32 28 170 G/M2 %100 ...
# 183    NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...
# 184    NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...
# 185    NE 30/1 PNY - SUPREM A.EN 32 28 170 G/M2 %100 ...
# Name: FabricDetail, Length: 186, dtype: object

# %%
#The Weight column is an integer type attribute that contains the weight of the product to be produced
#This attribute can be used in its raw form as a numeric attribute
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['Weight']
# Out:
# 0      125
# 1      125
# 2      125
# 3      125
# 4      125
#       ...
# 181    170
# 182    170
# 183    125
# 184    125
# 185    170
# Name: Weight, Length: 186, dtype: int64

# %%
#The Width column is an integer type attribute that contains the width of the fabric to be used
#This attribute can be used as a numeric attribute, but object data type is not a good choice for data of this type
#This attribute was not interpreted as integer when reading from pkl file via pandas library
#There must be a reason for this, this reason will be explored in this section
dataFrame['Width']
# Out:
# 0      150
# 1      150
# 2      150
# 3      150
# 4      150
#       ...
# 181    180
# 182    180
# 183    160
# 184    160
# 185    180
# Name: Width, Length: 186, dtype: object

# %%
#Map of rows containing numeric value in the Width column are being calculated
columnMap = dataFrame.applymap(np.isreal)['Width']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: Width, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the Width column are being printed
dataFrame[~columnMap]
# Out:
#                           Product           Color   ProductDetail FabricCode  \
# 71             M6061 JERSEYHOSE          BLAUGRAU  KADIN PANTOLON     2SP061
# 72             M6061 JERSEYHOSE    LOTUS YOGA AOP  KADIN PANTOLON     2SP061
# 73              M6062 JERSEYSHIRT  LOTUS YOGA AOP   KADIN T-SHIRT     2SP061
# 74     M6063 JERSEYKLEID OHNE ARM  LOTUS YOGA AOP    KADIN ELBISE     2SP061
# 75               M6064 JERSEYROCK  LOTUS YOGA AOP      KADIN ETEK     2SP061
# 76             M6065 LEGGING LANG         SCHWARZ  KADIN PANTOLON     2SP061
# 77             M6065 LEGGING LANG     AUBERGINE 2  KADIN PANTOLON     2SP061
# 78             M6065 LEGGING LANG        BLAUGRAU  KADIN PANTOLON     2SP061
# 79       M6066 JERSEYHOSE SPORTIV         SCHWARZ  KADIN PANTOLON     2SP061
# 80       M6066 JERSEYHOSE SPORTIV     AUBERGINE 2  KADIN PANTOLON     2SP061
# 81       M6066 JERSEYHOSE SPORTIV        BLAUGRAU  KADIN PANTOLON     2SP061
# 82             M6067 JERSEYTUNIKA         SCHWARZ    KADIN ELBISE     2SP061
# 83             M6067 JERSEYTUNIKA     AUBERGINE 2    KADIN ELBISE     2SP061
# 84             M6067 JERSEYTUNIKA        BLAUGRAU    KADIN ELBISE     2SP061
# 115            M6220 LEGGING KURZ         SCHWARZ  KADIN PANTOLON     2SP061
# 116            M6220 LEGGING KURZ     AUBERGINE 2  KADIN PANTOLON     2SP061
# 117            M6220 LEGGING KURZ        BLAUGRAU  KADIN PANTOLON     2SP061
# 153  M6100 BASICSHIRT SHORTSLEEVE      NATURWEISS   COCUK T-SHIRT     2SP061
# 154  M6100 BASICSHIRT SHORTSLEEVE           MALVE   COCUK T-SHIRT     2SP061
# 155  M6100 BASICSHIRT SHORTSLEEVE            MINT   COCUK T-SHIRT     2SP061
# 156  M6100 BASICSHIRT SHORTSLEEVE        BLAUGRAU   COCUK T-SHIRT     2SP061
# 157   M6101 BASICSHIRT LONGSLEEVE           MALVE   COCUK T-SHIRT     2SP061
# 158   M6101 BASICSHIRT LONGSLEEVE        BLAUGRAU   COCUK T-SHIRT     2SP061
# 159   M6101 BASICSHIRT LONGSLEEVE     AUBERGINE 2   COCUK T-SHIRT     2SP061
# 160            M6102 LEGGING LANG        BLAUGRAU  COCUK PANTOLON     2SP061
# 161            M6102 LEGGING LANG     AUBERGINE 2  COCUK PANTOLON     2SP061
# 162            M6102 LEGGING LANG         SCHWARZ  COCUK PANTOLON     2SP061
# 163             M6103 3/4 LEGGING           MALVE  COCUK PANTOLON     2SP061
# 164             M6103 3/4 LEGGING            MINT  COCUK PANTOLON     2SP061
# 165             M6103 3/4 LEGGING      NATURWEISS  COCUK PANTOLON     2SP061
#
#                                           FabricDetail  Weight      Width  \
# 71   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 72   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 73   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 74   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 75   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 76   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 77   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 78   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 79   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 80   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 81   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 82   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 83   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 84   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 153  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 154  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 155  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 156  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 157  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 158  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 159  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 160  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 161  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 162  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 163  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 164  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
# 165  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  170 - 175
#
#      ProductPart NotchLayer NotchQuantity  OrderQuantity  Quantity  Repair  \
# 71             6         28             2            270       288       7
# 72             6         28             2            270       300       2
# 73             4         66             2            400       440       1
# 74            13         50             3            320       358       0
# 75             4         77             3            400       440      12
# 76             2         75             4            400       396      15
# 77             2         75             4            400       440       6
# 78             2         75             4            400       423       5
# 79            14         66             3            280       264       3
# 80            14         66             3            280       312       9
# 81            14         66             3            280       288       3
# 82             4         29             2            250       250       1
# 83             4         29             2            250       280       3
# 84             4         29             2            250       260       9
# 115            2          ?             ?            400       379       8
# 116            2          ?             ?            400       442       8
# 117            2          ?             ?            400       400       7
# 153            5         22             2            210       249       0
# 154            5         22             2            215       186       7
# 155            5         22             2            210       235       2
# 156            5         22             2            200       224       1
# 157            5         28             2            205       205       8
# 158            5         28             2            210       213       7
# 159            5         28             2            210       234       5
# 160            2         28             2            220       246       3
# 161            2         28             2            220       246       7
# 162            2         28             2            220       246       3
# 163            2         39             3            210       232       8
# 164            2         39             3            210       232       9
# 165            2         39             3            210       232       6
#
#      Delivery  SecondQuality
# 71        280              8
# 72        297              3
# 73        437              3
# 74        353              5
# 75        438              2
# 76        392              4
# 77        433              7
# 78        414              9
# 79        253             11
# 80        303              9
# 81        279              9
# 82        235             15
# 83        275              5
# 84        254              6
# 115       377              2
# 116       440              2
# 117       394              6
# 153       244              5
# 154       177              9
# 155       228              7
# 156       222              2
# 157       197              8
# 158       205              8
# 159       227              7
# 160       244              2
# 161       245              1
# 162       243              3
# 163       231              1
# 164       230              2
# 165       228              4

# %%
#When the data is examined, an integer range can be seen instead of an integer value
#This needs to be fixed as the attribute cannot be used as integer as such

#Considering the range is in min-max format, the arithmetic mean of the min and max values ((min + max) / 2)
#can be used as the numeric value for this attribute
dataFrame.loc[~columnMap, 'Width'] = dataFrame.loc[~columnMap, 'Width'].apply(
    lambda x : (int(x.split('-')[0]) + int(x.split('-')[1])) / 2)
dataFrame[~columnMap]
# Out:
#                           Product           Color   ProductDetail FabricCode  \
# 71             M6061 JERSEYHOSE          BLAUGRAU  KADIN PANTOLON     2SP061
# 72             M6061 JERSEYHOSE    LOTUS YOGA AOP  KADIN PANTOLON     2SP061
# 73              M6062 JERSEYSHIRT  LOTUS YOGA AOP   KADIN T-SHIRT     2SP061
# 74     M6063 JERSEYKLEID OHNE ARM  LOTUS YOGA AOP    KADIN ELBISE     2SP061
# 75               M6064 JERSEYROCK  LOTUS YOGA AOP      KADIN ETEK     2SP061
# 76             M6065 LEGGING LANG         SCHWARZ  KADIN PANTOLON     2SP061
# 77             M6065 LEGGING LANG     AUBERGINE 2  KADIN PANTOLON     2SP061
# 78             M6065 LEGGING LANG        BLAUGRAU  KADIN PANTOLON     2SP061
# 79       M6066 JERSEYHOSE SPORTIV         SCHWARZ  KADIN PANTOLON     2SP061
# 80       M6066 JERSEYHOSE SPORTIV     AUBERGINE 2  KADIN PANTOLON     2SP061
# 81       M6066 JERSEYHOSE SPORTIV        BLAUGRAU  KADIN PANTOLON     2SP061
# 82             M6067 JERSEYTUNIKA         SCHWARZ    KADIN ELBISE     2SP061
# 83             M6067 JERSEYTUNIKA     AUBERGINE 2    KADIN ELBISE     2SP061
# 84             M6067 JERSEYTUNIKA        BLAUGRAU    KADIN ELBISE     2SP061
# 115            M6220 LEGGING KURZ         SCHWARZ  KADIN PANTOLON     2SP061
# 116            M6220 LEGGING KURZ     AUBERGINE 2  KADIN PANTOLON     2SP061
# 117            M6220 LEGGING KURZ        BLAUGRAU  KADIN PANTOLON     2SP061
# 153  M6100 BASICSHIRT SHORTSLEEVE      NATURWEISS   COCUK T-SHIRT     2SP061
# 154  M6100 BASICSHIRT SHORTSLEEVE           MALVE   COCUK T-SHIRT     2SP061
# 155  M6100 BASICSHIRT SHORTSLEEVE            MINT   COCUK T-SHIRT     2SP061
# 156  M6100 BASICSHIRT SHORTSLEEVE        BLAUGRAU   COCUK T-SHIRT     2SP061
# 157   M6101 BASICSHIRT LONGSLEEVE           MALVE   COCUK T-SHIRT     2SP061
# 158   M6101 BASICSHIRT LONGSLEEVE        BLAUGRAU   COCUK T-SHIRT     2SP061
# 159   M6101 BASICSHIRT LONGSLEEVE     AUBERGINE 2   COCUK T-SHIRT     2SP061
# 160            M6102 LEGGING LANG        BLAUGRAU  COCUK PANTOLON     2SP061
# 161            M6102 LEGGING LANG     AUBERGINE 2  COCUK PANTOLON     2SP061
# 162            M6102 LEGGING LANG         SCHWARZ  COCUK PANTOLON     2SP061
# 163             M6103 3/4 LEGGING           MALVE  COCUK PANTOLON     2SP061
# 164             M6103 3/4 LEGGING            MINT  COCUK PANTOLON     2SP061
# 165             M6103 3/4 LEGGING      NATURWEISS  COCUK PANTOLON     2SP061
#
#                                           FabricDetail  Weight  Width  \
# 71   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 72   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 73   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 74   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 75   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 76   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 77   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 78   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 79   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 80   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 81   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 82   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 83   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 84   NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 153  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 154  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 155  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 156  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 157  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 158  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 159  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 160  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 161  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 162  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 163  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 164  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
# 165  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190  172.5
#
#      ProductPart NotchLayer NotchQuantity  OrderQuantity  Quantity  Repair  \
# 71             6         28             2            270       288       7
# 72             6         28             2            270       300       2
# 73             4         66             2            400       440       1
# 74            13         50             3            320       358       0
# 75             4         77             3            400       440      12
# 76             2         75             4            400       396      15
# 77             2         75             4            400       440       6
# 78             2         75             4            400       423       5
# 79            14         66             3            280       264       3
# 80            14         66             3            280       312       9
# 81            14         66             3            280       288       3
# 82             4         29             2            250       250       1
# 83             4         29             2            250       280       3
# 84             4         29             2            250       260       9
# 115            2          ?             ?            400       379       8
# 116            2          ?             ?            400       442       8
# 117            2          ?             ?            400       400       7
# 153            5         22             2            210       249       0
# 154            5         22             2            215       186       7
# 155            5         22             2            210       235       2
# 156            5         22             2            200       224       1
# 157            5         28             2            205       205       8
# 158            5         28             2            210       213       7
# 159            5         28             2            210       234       5
# 160            2         28             2            220       246       3
# 161            2         28             2            220       246       7
# 162            2         28             2            220       246       3
# 163            2         39             3            210       232       8
# 164            2         39             3            210       232       9
# 165            2         39             3            210       232       6
#
#      Delivery  SecondQuality
# 71        280              8
# 72        297              3
# 73        437              3
# 74        353              5
# 75        438              2
# 76        392              4
# 77        433              7
# 78        414              9
# 79        253             11
# 80        303              9
# 81        279              9
# 82        235             15
# 83        275              5
# 84        254              6
# 115       377              2
# 116       440              2
# 117       394              6
# 153       244              5
# 154       177              9
# 155       228              7
# 156       222              2
# 157       197              8
# 158       205              8
# 159       227              7
# 160       244              2
# 161       245              1
# 162       243              3
# 163       231              1
# 164       230              2
# 165       228              4

# %%
#Shape of rows containing non-numeric value in the Width column are being printed
dataFrame[~dataFrame.applymap(np.isreal)['Width']].shape
# Out:
# (0, 15)

# %%
#Since there is no non-numeric data for Width column it can be converted to int64 data type,
#numbers with commas will be rounded to floor integer
dataFrame['Width'] = pd.to_numeric(dataFrame['Width']).astype(np.int64)
dataFrame['Width']
# Out:
# 0      150
# 1      150
# 2      150
# 3      150
# 4      150
#       ...
# 181    180
# 182    180
# 183    160
# 184    160
# 185    180
# Name: Width, Length: 186, dtype: int64

# %%
#The ProductPart column is an integer type attribute that contains
#the information of the number of parts contained in the product to be produced
#This attribute can be used in its raw form as a numeric attribute
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['ProductPart']
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 181    10
# 182     3
# 183     8
# 184     5
# 185     3
# Name: ProductPart, Length: 186, dtype: int64

# %%
#The NotchLayer column is an integer type attribute that contains the number of notch layers of the fabric to be used
#This attribute can be used as a numeric attribute, but object data type is not a good choice for data of this type
#This attribute was not interpreted as integer when reading from pkl file via pandas library
#There must be a reason for this, this reason will be explored in this section
dataFrame['NotchLayer']
# Out:
# 0      35
# 1      65
# 2      65
# 3      65
# 4      65
#        ..
# 181    28
# 182    28
# 183    28
# 184    28
# 185    28
# Name: NotchLayer, Length: 186, dtype: object

# %%
#Map of rows containing numeric value in the NotchLayer column are being calculated
columnMap = dataFrame.applymap(np.isreal)['NotchLayer']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: NotchLayer, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the NotchLayer column are being printed
dataFrame[~columnMap]
# Out:
#                                           Product        Color  \
# 51   M6042 NACHTHEMD MIT ÜBERSCHNITTENER SCHULTER   RINGEL AOP
# 64                  M6052 JERSEYKLEID WENDERINGEL  WENDERINGEL
# 65           M6053 JERSEYSHIRT WENDERINGEL HERREN  WENDERINGEL
# 66                 M6054 JERSEY SHIRT WENDERINGEL  WENDERINGEL
# 115                            M6220 LEGGING KURZ      SCHWARZ
# 116                            M6220 LEGGING KURZ  AUBERGINE 2
# 117                            M6220 LEGGING KURZ     BLAUGRAU
# 118                       M6015 WENDERINGEL KLEID  WENDERINGEL
# 119                     M6017 WENDERİNGEL SWEATER  WENDERINGEL
# 120                      M6018 WENDERİNGEL HOODİE  WENDERINGEL
# 121                     M6019 WENDERİNGEL BERMUDA  WENDERINGEL
#
#           ProductDetail FabricCode  \
# 51         KADIN ELBISE     2SP021
# 64         KADIN ELBISE     2IN007
# 65        ERKEK T-SHIRT     2IN007
# 66        KADIN T-SHIRT     2IN007
# 115      KADIN PANTOLON     2SP061
# 116      KADIN PANTOLON     2SP061
# 117      KADIN PANTOLON     2SP061
# 118        COCUK ELBISE     2IN007
# 119         COCUK SWEAT     2IN007
# 120     KIZ COCUK SWEAT     2IN007
# 121  KIZ COCUK PANTOLON     2IN007
#
#                                           FabricDetail  Weight  Width  \
# 51   NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...     125    160
# 64   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 65   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 66   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 118  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 119  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 120  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 121  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
#
#      ProductPart          NotchLayer NotchQuantity  OrderQuantity  Quantity  \
# 51             2  çizgili elde serim           NaN            310       294
# 64             4  çizgili elde serim           NaN            510       561
# 65             4  çizgili elde serim           NaN            380       418
# 66             4  çizgili elde serim           NaN            640       698
# 115            2                   ?             ?            400       379
# 116            2                   ?             ?            400       442
# 117            2                   ?             ?            400       400
# 118            2  çizgili elde serim           NaN            190       211
# 119            4  çizgili elde serim           NaN            220       248
# 120            7  çizgili elde serim           NaN            255       285
# 121            6  çizgili elde serim           NaN            195       221
#
#      Repair  Delivery  SecondQuality
# 51        6       290              4
# 64        6       550             11
# 65       12       403             15
# 66       15       690              8
# 115       8       377              2
# 116       8       440              2
# 117       7       394              6
# 118       6       207              4
# 119       4       240              8
# 120       2       282              3
# 121       3       222             -1

# %%
#When the data is examined, it is seen that the non-numeric NotchLayer values takes two different values

#1) ?(Question Mark): This value indicates that the data in the relevant cell is unknown
#In such cases, the data can be cleared by completely deleting the rows of data that do not exist in the cell
#Or especially in such cases where the quantity of data is low 
#and each row is valuable, the relevant cells can be filled using statistical methods
#This method will be applied as no data rows are wanted to be lost in the current situation

#Map of rows containing value of '?' in the NotchLayer column are being calculated
columnMap = dataFrame['NotchLayer'] == '?'
columnMap
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# Name: NotchLayer, Length: 186, dtype: bool

# %%
#Rows containing value of '?' in the NotchLayer column are being printed
dataFrame[columnMap]
# Out:
#                 Product        Color   ProductDetail FabricCode  \
# 115  M6220 LEGGING KURZ      SCHWARZ  KADIN PANTOLON     2SP061
# 116  M6220 LEGGING KURZ  AUBERGINE 2  KADIN PANTOLON     2SP061
# 117  M6220 LEGGING KURZ     BLAUGRAU  KADIN PANTOLON     2SP061
#
#                                           FabricDetail  Weight  Width  \
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
#
#      ProductPart NotchLayer NotchQuantity  OrderQuantity  Quantity  Repair  \
# 115            2          ?             ?            400       379       8
# 116            2          ?             ?            400       442       8
# 117            2          ?             ?            400       400       7
#
#      Delivery  SecondQuality
# 115       377              2
# 116       440              2
# 117       394              6

# %%
#cells containing '?' in the NotchLayer column are filled with the mean value of numeric values in the NotchLayer column
dataFrame.loc[columnMap, 'NotchLayer'] =  dataFrame[dataFrame.applymap(np.isreal)['NotchLayer']]['NotchLayer'].mean()
dataFrame[columnMap]
# Out:
#                 Product        Color   ProductDetail FabricCode  \
# 115  M6220 LEGGING KURZ      SCHWARZ  KADIN PANTOLON     2SP061
# 116  M6220 LEGGING KURZ  AUBERGINE 2  KADIN PANTOLON     2SP061
# 117  M6220 LEGGING KURZ     BLAUGRAU  KADIN PANTOLON     2SP061
#
#                                           FabricDetail  Weight  Width  \
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...     190    172
#
#      ProductPart NotchLayer NotchQuantity  OrderQuantity  Quantity  Repair  \
# 115            2  46.491429             ?            400       379       8
# 116            2  46.491429             ?            400       442       8
# 117            2  46.491429             ?            400       400       7
#
#      Delivery  SecondQuality
# 115       377              2
# 116       440              2
# 117       394              6

# %%
#Map of rows containing numeric value in the NotchLayer column are being calculated
columnMap = dataFrame.applymap(np.isreal)['NotchLayer']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: NotchLayer, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the NotchLayer column are being printed
dataFrame[~columnMap]
# Out:
#                                           Product        Color  \
# 51   M6042 NACHTHEMD MIT ÜBERSCHNITTENER SCHULTER   RINGEL AOP
# 64                  M6052 JERSEYKLEID WENDERINGEL  WENDERINGEL
# 65           M6053 JERSEYSHIRT WENDERINGEL HERREN  WENDERINGEL
# 66                 M6054 JERSEY SHIRT WENDERINGEL  WENDERINGEL
# 118                       M6015 WENDERINGEL KLEID  WENDERINGEL
# 119                     M6017 WENDERİNGEL SWEATER  WENDERINGEL
# 120                      M6018 WENDERİNGEL HOODİE  WENDERINGEL
# 121                     M6019 WENDERİNGEL BERMUDA  WENDERINGEL
#
#           ProductDetail FabricCode  \
# 51         KADIN ELBISE     2SP021
# 64         KADIN ELBISE     2IN007
# 65        ERKEK T-SHIRT     2IN007
# 66        KADIN T-SHIRT     2IN007
# 118        COCUK ELBISE     2IN007
# 119         COCUK SWEAT     2IN007
# 120     KIZ COCUK SWEAT     2IN007
# 121  KIZ COCUK PANTOLON     2IN007
#
#                                           FabricDetail  Weight  Width  \
# 51   NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...     125    160
# 64   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 65   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 66   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 118  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 119  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 120  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
# 121  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....     250    180
#
#      ProductPart          NotchLayer NotchQuantity  OrderQuantity  Quantity  \
# 51             2  çizgili elde serim           NaN            310       294
# 64             4  çizgili elde serim           NaN            510       561
# 65             4  çizgili elde serim           NaN            380       418
# 66             4  çizgili elde serim           NaN            640       698
# 118            2  çizgili elde serim           NaN            190       211
# 119            4  çizgili elde serim           NaN            220       248
# 120            7  çizgili elde serim           NaN            255       285
# 121            6  çizgili elde serim           NaN            195       221
#
#      Repair  Delivery  SecondQuality
# 51        6       290              4
# 64        6       550             11
# 65       12       403             15
# 66       15       690              8
# 118       6       207              4
# 119       4       240              8
# 120       2       282              3
# 121       3       222             -1

# %%
#2) sentence: this value is a sentence in Turkish
#This sentence can be interpreted as the NotchLayer data loses its meaning because some operations are done manually
#It also seems that the NotchQuantity data loses its meaning
#This proves that NotchLayer and NotchQuantity data are two variables of the same process

#In cases where these two attributes become meaningless, these values will be set to 0
#and an extra attribute will be defined to indicate that these values become meaningless / a different operation is applied
dataFrame.loc[~columnMap, 'NotchLayer'] = 0
dataFrame.loc[~columnMap, 'NotchQuantity'] = 0
dataFrame.insert(loc=5, column='IsManualProcess', value=~columnMap)
dataFrame[~columnMap]
# Out:
#                                           Product        Color  \
# 51   M6042 NACHTHEMD MIT ÜBERSCHNITTENER SCHULTER   RINGEL AOP
# 64                  M6052 JERSEYKLEID WENDERINGEL  WENDERINGEL
# 65           M6053 JERSEYSHIRT WENDERINGEL HERREN  WENDERINGEL
# 66                 M6054 JERSEY SHIRT WENDERINGEL  WENDERINGEL
# 118                       M6015 WENDERINGEL KLEID  WENDERINGEL
# 119                     M6017 WENDERİNGEL SWEATER  WENDERINGEL
# 120                      M6018 WENDERİNGEL HOODİE  WENDERINGEL
# 121                     M6019 WENDERİNGEL BERMUDA  WENDERINGEL
#
#           ProductDetail FabricCode  \
# 51         KADIN ELBISE     2SP021
# 64         KADIN ELBISE     2IN007
# 65        ERKEK T-SHIRT     2IN007
# 66        KADIN T-SHIRT     2IN007
# 118        COCUK ELBISE     2IN007
# 119         COCUK SWEAT     2IN007
# 120     KIZ COCUK SWEAT     2IN007
# 121  KIZ COCUK PANTOLON     2IN007
#
#                                           FabricDetail  IsManualProcess  \
# 51   NE 40/1 PNY - SUPREM A.EN 32 28 125 G/M2 %100 ...             True
# 64   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 65   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 66   NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 118  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 119  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 120  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
# 121  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....             True
#
#      Weight  Width  ProductPart NotchLayer NotchQuantity  OrderQuantity  \
# 51      125    160            2          0             0            310
# 64      250    180            4          0             0            510
# 65      250    180            4          0             0            380
# 66      250    180            4          0             0            640
# 118     250    180            2          0             0            190
# 119     250    180            4          0             0            220
# 120     250    180            7          0             0            255
# 121     250    180            6          0             0            195
#
#      Quantity  Repair  Delivery  SecondQuality
# 51        294       6       290              4
# 64        561       6       550             11
# 65        418      12       403             15
# 66        698      15       690              8
# 118       211       6       207              4
# 119       248       4       240              8
# 120       285       2       282              3
# 121       221       3       222             -1

# %%
#Map of rows containing numeric value in the NotchLayer column are being calculated
columnMap = dataFrame.applymap(np.isreal)['NotchLayer']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: NotchLayer, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the NotchLayer column are being printed
dataFrame[~columnMap].shape
# Out:
# (0, 16)

# %%
#Since there is no non-numeric data for NotchLayer column it can be converted to int64 data type,
#numbers with commas will be rounded to floor integer
dataFrame['NotchLayer'] = pd.to_numeric(dataFrame['NotchLayer']).astype(np.int64)
dataFrame['NotchLayer']
# Out:
# 0      35
# 1      65
# 2      65
# 3      65
# 4      65
#        ..
# 181    28
# 182    28
# 183    28
# 184    28
# 185    28
# Name: NotchLayer, Length: 186, dtype: int64

# %%
#New boolean type column added is being printed
dataFrame['IsManualProcess']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# Name: IsManualProcess, Length: 186, dtype: bool

# %%
#The NotchQuantity column is an integer type attribute that contains the number of notch of the fabric to be used
#This attribute can be used as a numeric attribute, but object data type is not a good choice for data of this type
#This attribute was not interpreted as integer when reading from pkl file via pandas library
#There must be a reason for this, this reason will be explored in this section
dataFrame['NotchQuantity']
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 181    2
# 182    2
# 183    2
# 184    2
# 185    2
# Name: NotchQuantity, Length: 186, dtype: object

# %%
#NotchQuantity column was partially edited when editing Notch Layer column
#At this stage, the NotchQuantity column will be checked again and the necessary actions will be taken

#Map of rows containing numeric value in the NotchQuantity column are being calculated
columnMap = dataFrame.applymap(np.isreal)['NotchQuantity']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: NotchQuantity, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the NotchQuantity column are being printed
dataFrame[~columnMap]
# Out:
#                 Product        Color   ProductDetail FabricCode  \
# 115  M6220 LEGGING KURZ      SCHWARZ  KADIN PANTOLON     2SP061
# 116  M6220 LEGGING KURZ  AUBERGINE 2  KADIN PANTOLON     2SP061
# 117  M6220 LEGGING KURZ     BLAUGRAU  KADIN PANTOLON     2SP061
#
#                                           FabricDetail  IsManualProcess  \
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
#
#      Weight  Width  ProductPart  NotchLayer NotchQuantity  OrderQuantity  \
# 115     190    172            2          46             ?            400
# 116     190    172            2          46             ?            400
# 117     190    172            2          46             ?            400
#
#      Quantity  Repair  Delivery  SecondQuality
# 115       379       8       377              2
# 116       442       8       440              2
# 117       400       7       394              6

# %%
#As can be seen, all of the non-numeric cells contains '?' value
#cells containing '?' in the NotchQuantity column are filled with the mean value of numeric values in the NotchQuantity column
dataFrame.loc[~columnMap, 'NotchQuantity'] =  dataFrame[columnMap]['NotchQuantity'].mean()
dataFrame[~columnMap]
# Out:
#                 Product        Color   ProductDetail FabricCode  \
# 115  M6220 LEGGING KURZ      SCHWARZ  KADIN PANTOLON     2SP061
# 116  M6220 LEGGING KURZ  AUBERGINE 2  KADIN PANTOLON     2SP061
# 117  M6220 LEGGING KURZ     BLAUGRAU  KADIN PANTOLON     2SP061
#
#                                           FabricDetail  IsManualProcess  \
# 115  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
# 116  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
# 117  NE 30/1 PNY 40DE - SUPREM A.EN 32 28 190 G/M2 ...            False
#
#      Weight  Width  ProductPart  NotchLayer NotchQuantity  OrderQuantity  \
# 115     190    172            2          46       2.47541            400
# 116     190    172            2          46       2.47541            400
# 117     190    172            2          46       2.47541            400
#
#      Quantity  Repair  Delivery  SecondQuality
# 115       379       8       377              2
# 116       442       8       440              2
# 117       400       7       394              6

# %%
#Map of rows containing numeric value in the NotchLayer column are being calculated
columnMap = dataFrame.applymap(np.isreal)['NotchQuantity']
columnMap
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# Name: NotchQuantity, Length: 186, dtype: bool

# %%
#Rows containing non-numeric value in the NotchQuantity column are being printed
dataFrame[~columnMap].shape
# Out:
# (0, 16)

# %%
#Since there is no non-numeric data for NotchQuantity column it can be converted to int64 data type,
#numbers with commas will be rounded to floor integer
dataFrame['NotchQuantity'] = pd.to_numeric(dataFrame['NotchQuantity']).astype(np.int64)
dataFrame['NotchQuantity']
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 181    2
# 182    2
# 183    2
# 184    2
# 185    2
# Name: NotchQuantity, Length: 186, dtype: int64

# %%
#The OrderQuantity column is an integer type attribute that contains the number of products ordered
#This attribute can be used in its raw form as a numeric attribute
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['OrderQuantity']
# Out:
# 0      375
# 1      375
# 2      375
# 3      375
# 4      375
#       ...
# 181    250
# 182    205
# 183    205
# 184    155
# 185    200
# Name: OrderQuantity, Length: 186, dtype: int64

# %%
#The Quantity column is an integer type attribute that contains the number of products produced
#This attribute will be used to produce the data to be predicted(output)
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['Quantity']
# Out:
# 0      405
# 1      414
# 2      389
# 3      414
# 4      414
#       ...
# 181    260
# 182    206
# 183    228
# 184    176
# 185    224
# Name: Quantity, Length: 186, dtype: int64

# %%
#The Repair column is an integer type attribute that contains the number of defective products which successfully repaired
#This attribute will be used to produce the data to be predicted(output)
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['Repair']
# Out:
# 0      20
# 1      22
# 2      19
# 3      18
# 4      16
#        ..
# 181     6
# 182     4
# 183     3
# 184     2
# 185     1
# Name: Repair, Length: 186, dtype: int64

# %%
#The Delivery column is an integer type attribute that contains
#the number of products that has quality which can be delivered to the customer
#This attribute will be used to produce the data to be predicted(output)
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['Delivery']
# Out:
# 0      399
# 1      411
# 2      378
# 3      406
# 4      411
#       ...
# 181    258
# 182    203
# 183    213
# 184    173
# 185    220
# Name: Delivery, Length: 186, dtype: int64

# %%
#The SecondQuality column is an integer type attribute that contains
#the number of products that cannot reach the quality that can be delivered to the customer even after repair
#This attribute will be used to produce the data to be predicted(output)
#Since int64 data type is a good choice for data of this type, no action is required in this section
dataFrame['SecondQuality']
# Out:
# 0       6
# 1       3
# 2      11
# 3       8
# 4       3
#        ..
# 181     2
# 182     3
# 183    15
# 184     3
# 185     4
# Name: SecondQuality, Length: 186, dtype: int64

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product          186 non-null    object
#  1   Color            186 non-null    object
#  2   ProductDetail    186 non-null    object
#  3   FabricCode       186 non-null    object
#  4   FabricDetail     186 non-null    object
#  5   IsManualProcess  186 non-null    bool
#  6   Weight           186 non-null    int64
#  7   Width            186 non-null    int64
#  8   ProductPart      186 non-null    int64
#  9   NotchLayer       186 non-null    int64
#  10  NotchQuantity    186 non-null    int64
#  11  OrderQuantity    186 non-null    int64
#  12  Quantity         186 non-null    int64
#  13  Repair           186 non-null    int64
#  14  Delivery         186 non-null    int64
#  15  SecondQuality    186 non-null    int64
# dtypes: bool(1), int64(10), object(5)
# memory usage: 22.1+ KB

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  186.000000  186.000000   186.000000  186.000000     186.000000
# mean   165.241935  159.435484     4.801075   44.483871       2.467742
# std     36.999935   15.936653     2.289388   21.042615       0.792896
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   31.000000       2.000000
# 50%    172.500000  160.000000     4.000000   39.000000       3.000000
# 75%    190.000000  171.500000     5.000000   58.000000       3.000000
# max    250.000000  180.000000    14.000000  111.000000       4.000000
#
#        OrderQuantity    Quantity      Repair    Delivery  SecondQuality
# count     186.000000  186.000000  186.000000  186.000000     186.000000
# mean      294.489247  317.209677    6.387097  309.311828       7.897849
# std       113.160409  123.932912    4.987622  122.498051       6.454439
# min       100.000000  110.000000    0.000000  112.000000      -2.000000
# 25%       206.250000  224.000000    3.000000  217.000000       4.000000
# 50%       250.000000  272.000000    6.000000  265.000000       6.000000
# 75%       380.000000  414.000000    8.000000  407.500000      10.000000
# max       640.000000  698.000000   30.000000  690.000000      38.000000

# %%
#When statistical information of dataFrame is examined,
#it can be seen that the minimum SecondQuality value is -2 which is meaningless

#Because SecondQuality value indicates that how many products are of a quality that cannot be delivered to customer
#It doesn't make much sense that -2 products were produced with a defect.

#Let's take a look at the situation
mask = dataFrame['SecondQuality'] < 0
dataFrame[mask]
# Out:
#                        Product            Color       ProductDetail  \
# 121  M6019 WENDERİNGEL BERMUDA      WENDERINGEL  KIZ COCUK PANTOLON
# 175  M6142 HAARBAND MİT KNOTEN  AOP BLUMENWIESE      COCUK AKSESUAR
#
#     FabricCode                                       FabricDetail  \
# 121     2IN007  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....
# 175     2SP309  NE 30/1 PNY - SUPREM A.EN 32 28 170 G/M2 %100 ...
#
#      IsManualProcess  Weight  Width  ProductPart  NotchLayer  NotchQuantity  \
# 121             True     250    180            6           0              0
# 175            False     170    180            5          22              1
#
#      OrderQuantity  Quantity  Repair  Delivery  SecondQuality
# 121            195       221       3       222             -1
# 175            100       110       0       112             -2

# %%
#In this situation, it can be seen that the SecondQuality value is -1,
#when product quantity produced is 221 and delivered quantity is 222

#Similarly, it can be seen that the SecondQuality value is -2,
#when product quantity produced is 110 and delivered quantity is 112

#This situation can be interpreted as 
#the facility directs the surplus products produced for previous orders to the customer in these orders

#Can be considered that a similar situation may apply to rows without a negative Second Quality value
#This will reduce reliability and accuracy in predicting SecondQuality values,
#as it may mean that the SecondQuality column does not represent actual values

#For now, rows with SecondQuality value less than 0 will have SecondQuality value equal to 0,
#Quantity value will be equal to Delivery value since it is meaningless to deliver more than produced

dataFrame.loc[mask, 'Delivery'] = dataFrame.loc[mask, 'Quantity']
dataFrame.loc[mask, 'SecondQuality'] = 0
dataFrame[mask]
# Out:
#                        Product            Color       ProductDetail  \
# 121  M6019 WENDERİNGEL BERMUDA      WENDERINGEL  KIZ COCUK PANTOLON
# 175  M6142 HAARBAND MİT KNOTEN  AOP BLUMENWIESE      COCUK AKSESUAR
#
#     FabricCode                                       FabricDetail  \
# 121     2IN007  NE 30/1 30/1 PNY PNY - INTERLOK DOUBLE FACE A....
# 175     2SP309  NE 30/1 PNY - SUPREM A.EN 32 28 170 G/M2 %100 ...
#
#      IsManualProcess  Weight  Width  ProductPart  NotchLayer  NotchQuantity  \
# 121             True     250    180            6           0              0
# 175            False     170    180            5          22              1
#
#      OrderQuantity  Quantity  Repair  Delivery  SecondQuality
# 121            195       221       3       221              0
# 175            100       110       0       110              0

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product          186 non-null    object
#  1   Color            186 non-null    object
#  2   ProductDetail    186 non-null    object
#  3   FabricCode       186 non-null    object
#  4   FabricDetail     186 non-null    object
#  5   IsManualProcess  186 non-null    bool
#  6   Weight           186 non-null    int64
#  7   Width            186 non-null    int64
#  8   ProductPart      186 non-null    int64
#  9   NotchLayer       186 non-null    int64
#  10  NotchQuantity    186 non-null    int64
#  11  OrderQuantity    186 non-null    int64
#  12  Quantity         186 non-null    int64
#  13  Repair           186 non-null    int64
#  14  Delivery         186 non-null    int64
#  15  SecondQuality    186 non-null    int64
# dtypes: bool(1), int64(10), object(5)
# memory usage: 22.1+ KB

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  186.000000  186.000000   186.000000  186.000000     186.000000
# mean   165.241935  159.435484     4.801075   44.483871       2.467742
# std     36.999935   15.936653     2.289388   21.042615       0.792896
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   31.000000       2.000000
# 50%    172.500000  160.000000     4.000000   39.000000       3.000000
# 75%    190.000000  171.500000     5.000000   58.000000       3.000000
# max    250.000000  180.000000    14.000000  111.000000       4.000000
#
#        OrderQuantity    Quantity      Repair    Delivery  SecondQuality
# count     186.000000  186.000000  186.000000  186.000000     186.000000
# mean      294.489247  317.209677    6.387097  309.295699       7.913978
# std       113.160409  123.932912    4.987622  122.519425       6.432445
# min       100.000000  110.000000    0.000000  110.000000       0.000000
# 25%       206.250000  224.000000    3.000000  217.000000       4.000000
# 50%       250.000000  272.000000    6.000000  265.000000       6.000000
# 75%       380.000000  414.000000    8.000000  407.500000      10.000000
# max       640.000000  698.000000   30.000000  690.000000      38.000000

# %%
#dataFrame cleaned of columns that will not be used is being saved as pkl file
dataFrame.to_pickle("../Data/CleanedData/FabricWaste.pkl")
