# %% [markdown]
# # Factorial Analysis of Mixed Data Analysis 6
#
# In this notebook file, jointplots will be plotted for PC18-PC22 input and SecondQualityRate

# %%
#Libraries are being imported
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlibVersion
import seaborn as sns

# %%
#Settings for Graphic Libraries are being made
# %matplotlib inline
sns.set_style('whitegrid')

# %%
#Library versions are being printed
print('pandas Version: ' + pd.__version__)
print('matplotlib Version: ' + matplotlibVersion)
print('seaborn Version: ' + sns.__version__)
# Out:
# pandas Version: 1.5.2
# matplotlib Version: 3.6.2
# seaborn Version: 0.12.1

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/AnalysisFAMD/FabricWaste.pkl")
dataFrame.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -1.555507  0.420595  0.005030 -1.935320 -1.516163  0.035307 -0.092359
# 1 -2.808011 -0.943748 -0.850723 -1.189402 -0.863034 -0.256698 -0.974828
# 2 -2.586685 -0.639300 -0.090313 -1.479553 -1.711759 -0.157235 -1.324735
# 3 -1.674960  0.162357  0.287865 -2.126192 -1.501726  0.111705 -0.932359
# 4 -1.639025  0.537081 -0.098786 -1.501355 -1.505985  0.452858 -0.602762
#
#         PC7       PC8       PC9  ...  DefectRate  PrintError  SewingError  \
# 0 -0.851427 -1.051567  0.095063  ...    0.064198           4            0
# 1  0.999649 -0.909815  0.190603  ...    0.060386           0            2
# 2  0.456007 -1.331362 -0.345296  ...    0.077121           1            5
# 3 -0.184961 -1.451265 -0.046914  ...    0.062802           0            4
# 4  0.626860 -0.945599 -0.285213  ...    0.045894           0            3
#
#    FabricStain  FabricError  EmbroideryError  MeasureError  SecondQuality  \
# ...

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      200 non-null    float64
#  1   PC1                      200 non-null    float64
#  2   PC2                      200 non-null    float64
#  3   PC3                      200 non-null    float64
#  4   PC4                      200 non-null    float64
#  5   PC5                      200 non-null    float64
#  6   PC6                      200 non-null    float64
#  7   PC7                      200 non-null    float64
#  8   PC8                      200 non-null    float64
#  9   PC9                      200 non-null    float64
#  10  PC10                     200 non-null    float64
#  11  PC11                     200 non-null    float64
#  12  PC12                     200 non-null    float64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#                 PC0         PC1           PC2           PC3         PC4  \
# count  2.000000e+02  200.000000  2.000000e+02  2.000000e+02  200.000000
# mean  -8.881784e-18    0.000000 -7.105427e-17 -2.131628e-16    0.000000
# std    2.705285e+00    2.524125  2.299354e+00  2.099280e+00    1.862093
# min   -2.868326e+00   -5.000387 -6.817076e+00 -4.074451e+00   -4.098815
# 25%   -1.666041e+00   -1.802093 -7.509226e-01 -1.509021e+00   -1.387319
# 50%   -7.179435e-01   -0.199173 -2.306795e-01 -4.752648e-01   -0.649218
# 75%    8.028284e-01    1.919508  3.608445e-01  1.141637e+00    1.014746
# max    1.229565e+01    5.041269  9.894058e+00  6.655812e+00    5.603761
#
#                 PC5           PC6           PC7           PC8           PC9  \
# count  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02
# mean   2.131628e-16 -3.552714e-17  1.776357e-16  1.065814e-16 -3.552714e-17
# std    1.726438e+00  1.630424e+00  1.468617e+00  1.368700e+00  1.345985e+00
# ...

# %%
#jointplot for PC18 and SecondQualityRate features is being plotted
sns.jointplot(x = 'PC18', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for PC19 and SecondQualityRate features is being plotted
sns.jointplot(x = 'PC19', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for PC20 and SecondQualityRate features is being plotted
sns.jointplot(x = 'PC20', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for PC21 and SecondQualityRate features is being plotted
sns.jointplot(x = 'PC21', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for PC22 and SecondQualityRate features is being plotted
sns.jointplot(x = 'PC22', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')
