# %% [markdown]
# # Twenty Seventh Data AnalysisProcess
#
# In this notebook file, jointplots will be plotted for OrderQuantity input and all Output Rates

# %%
#Libraries are being imported
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlibVersion
import seaborn as sns

# %%
#Settings for Graphic Libraries are being made
# %matplotlib inline
sns.set_style('whitegrid')

# %%
#Library versions are being printed
print('pandas Version: ' + pd.__version__)
print('matplotlib Version: ' + matplotlibVersion)
print('seaborn Version: ' + sns.__version__)
# Out:
# pandas Version: 1.5.2
# matplotlib Version: 3.6.2
# seaborn Version: 0.12.1

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/DataAnalysis/FabricWaste.pkl")
dataFrame.head()
# Out:
#   ProductTypeCategory ProductType Maturity  Gender     FabricType ColorType  \
# 0                 Top     T-Shirt    Adult  Female  Single Jersey        SC
# 1                 Top     T-Shirt    Adult  Female  Single Jersey        SC
# 2                 Top     T-Shirt    Adult  Female  Single Jersey        SC
# 3                 Top     T-Shirt    Adult  Female  Single Jersey        SC
# 4                 Top     T-Shirt    Adult  Female  Single Jersey        SC
#
#   CustomerDefinedCategory  IsManualProcess  Red  Green  ...  DefectRate  \
# 0                Greenish            False   42     47  ...    0.064198
# 1               Orangeish            False  255    229  ...    0.060386
# 2                  Bluish            False  173    216  ...    0.077121
# 3                  Bluish            False    0     95  ...    0.062802
# 4                 Pinkish            False   72     50  ...    0.045894
#
#    PrintError  SewingError  FabricStain  FabricError  EmbroideryError  \
# ...

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ProductTypeCategory      200 non-null    object
#  1   ProductType              200 non-null    object
#  2   Maturity                 200 non-null    object
#  3   Gender                   200 non-null    object
#  4   FabricType               200 non-null    object
#  5   ColorType                200 non-null    object
#  6   CustomerDefinedCategory  200 non-null    object
#  7   IsManualProcess          200 non-null    bool
#  8   Red                      200 non-null    int64
#  9   Green                    200 non-null    int64
#  10  Blue                     200 non-null    int64
#  11  Pus                      200 non-null    int64
#  12  Fine                     200 non-null    int64
#  13  G/M2                     200 non-null    int64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#               Red       Green        Blue         Pus        Fine        G/M2  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   106.710000  100.380000  113.625000   32.330000   25.210000  171.500000
# std     97.684272   92.426451   86.773397    0.744224    3.933607   45.514921
# min     -1.000000   -1.000000   -1.000000   32.000000   14.000000  125.000000
# 25%      0.000000    0.000000    3.000000   32.000000   22.000000  125.000000
# 50%     94.000000   90.000000  112.000000   32.000000   28.000000  175.000000
# 75%    218.000000  186.250000  200.250000   32.000000   28.000000  190.000000
# max    255.000000  255.000000  255.000000   34.000000   28.000000  320.000000
#
#            Cotton       Nylon       Fiber       Linen  ...  DefectRate  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     0.915950    0.001500    0.012800    0.045000  ...    0.044340
# ...

# %%
#jointplot for OrderQuantity and PrintErrorRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'PrintErrorRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and SewingErrorRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'SewingErrorRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and FabricStainRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'FabricStainRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and FabricErrorRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'FabricErrorRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and EmbroideryErrorRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'EmbroideryErrorRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and MeasureErrorRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'MeasureErrorRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and SecondQualityRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'SecondQualityRate', data = dataFrame, kind = 'reg')

# %%
#jointplot for OrderQuantity and DefectRate features is being plotted
sns.jointplot(x = 'OrderQuantity', y = 'DefectRate', data = dataFrame, kind = 'reg')
