# %% [markdown]
# # Third Data Preparation Process
#
# In this notebook file, the dataset provided by the customer will be eddited for general purposes.
#
# The Product feature will be examined in depth.

# %%
#Library is being imported
import pandas as pd

# %%
#Library version is being printed
print('pandas Version: ' + pd.__version__)
# Out:
# pandas Version: 1.5.2

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/CleanedData/FabricWaste.pkl")
dataFrame.head()
# Out:
#                       Product        Color  ProductDetail FabricCode  \
# 0  M6030 JERSEY SHIRT LANGARM        PINIE  KADIN T-SHIRT     2SP050
# 1  M6030 JERSEY SHIRT LANGARM     PFIRSICH  KADIN T-SHIRT     2SP050
# 2  M6030 JERSEY SHIRT LANGARM     HELLBLAU  KADIN T-SHIRT     2SP050
# 3  M6030 JERSEY SHIRT LANGARM   PETROLBLAU  KADIN T-SHIRT     2SP050
# 4  M6030 JERSEY SHIRT LANGARM  AUBERGINE 2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  ...  Quantity  Repair  Delivery  \
# ...

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 0 to 208
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product          206 non-null    object
#  1   Color            206 non-null    object
#  2   ProductDetail    206 non-null    object
#  3   FabricCode       206 non-null    object
#  4   FabricDetail     206 non-null    object
#  5   IsManualProcess  206 non-null    bool
#  6   Weight           206 non-null    int64
#  7   Width            206 non-null    int64
#  8   ProductPart      206 non-null    int64
#  9   NotchLayer       206 non-null    int64
#  10  NotchQuantity    206 non-null    int64
#  11  OrderQuantity    206 non-null    int64
#  12  Quantity         206 non-null    int64
#  13  Repair           206 non-null    int64
#  14  Delivery         206 non-null    int64
#  15  PrintError       206 non-null    int64
#  16  SewingError      206 non-null    int64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  206.000000  206.000000   206.000000  206.000000     206.000000
# mean   171.601942  161.451456     4.902913   64.621359       2.864078
# std     45.318459   16.988808     2.433564   73.558421       1.571382
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   33.000000       2.000000
# 50%    175.000000  165.000000     4.000000   44.000000       3.000000
# 75%    190.000000  172.000000     5.000000   66.750000       3.000000
# max    320.000000  195.000000    14.000000  610.000000      14.000000
#
#        OrderQuantity     Quantity      Repair     Delivery  PrintError  \
# count     206.000000   206.000000  206.000000   206.000000  206.000000
# mean      528.956311   574.305825    8.179612   559.199029    4.917476
# std       812.807992   891.308093    8.979205   866.214970   18.322796
# ...

# %%
#Number of unique values of each column are being printed
dataFrame.nunique()
# Out:
# Product            100
# Color               50
# ProductDetail       24
# FabricCode          19
# FabricDetail        19
# IsManualProcess      2
# Weight              11
# Width               12
# ProductPart         12
# NotchLayer          47
# NotchQuantity       10
# OrderQuantity       56
# Quantity           126
# Repair              30
# Delivery           152
# PrintError          29
# SewingError         31
# FabricStain          9
# FabricError         16
# EmbroideryError      7
# MeasureError         8
# SecondQuality       43
# dtype: int64

# %%
#Too many unique values for a categorical attribute in Product column
#In order to use this feature effectively, the values in the column should be processed
#Unique Product are being printed
dataFrame['Product'].unique()
# Out:
# array(['M6030 JERSEY SHIRT LANGARM', 'M6031 JERSEY SHIRT KURZARM',
#        'M6032 JERSEY TOP', 'M6033 JERSEY SHIRT WICKELOPTIK',
#        'M6034 JERSEY HOSE ORIENT',
#        'M6035 JERSEY SHIRT KURZARM MIT FRONTPRINT',
#        'M6036 JERSEY SHIRT LANGARM MIT KETTELKANTE',
#        'M6037 JERSEY SHIRT 1/2 ARM MIT KETTELKANTE',
#        'M6038 JERSEY TOP MIT KETTELKANTE', 'M6039 JERSEYBLUSE',
#        'M6041 JERSEYJKLEID IN WICKELOPTIK',
#        'M6042 NACHTHEMD MIT ÜBERSCHNITTENER SCHULTER',
#        'M6043 SCHLAFANZUG LANG HERREN', 'M6044 SCHLAFANZUG KURZ HERREN',
#        'M6045 NACHTHEMD MIT HALBARM', 'M6046 PYJAMAHOSE',
#        'M6047 PYJAMAHOSE KURZ', 'M6048 PYJAMAHOSE',
#        'M6049 JERSEYSHIRT KURZARM', 'M6050 NACHTHEMD KURZARM',
#        'M6051 PYJAMAHOSE', 'M6052 JERSEYKLEID WENDERINGEL',
#        'M6053 JERSEYSHIRT WENDERINGEL HERREN',
#        'M6054 JERSEY SHIRT WENDERINGEL',
#        'M6055 JERSEYBLUSE MIT KURZEM ARM', 'M6056 JERSEYROCK',
# ...

# %%
#Since the information that can be extracted from Product column can be extracted in more detail from other columns
#Product column is being removed from dataFrame
dataFrame.drop('Product', axis = 1, inplace = True)

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 0 to 208
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Color            206 non-null    object
#  1   ProductDetail    206 non-null    object
#  2   FabricCode       206 non-null    object
#  3   FabricDetail     206 non-null    object
#  4   IsManualProcess  206 non-null    bool
#  5   Weight           206 non-null    int64
#  6   Width            206 non-null    int64
#  7   ProductPart      206 non-null    int64
#  8   NotchLayer       206 non-null    int64
#  9   NotchQuantity    206 non-null    int64
#  10  OrderQuantity    206 non-null    int64
#  11  Quantity         206 non-null    int64
#  12  Repair           206 non-null    int64
#  13  Delivery         206 non-null    int64
#  14  PrintError       206 non-null    int64
#  15  SewingError      206 non-null    int64
#  16  FabricStain      206 non-null    int64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  206.000000  206.000000   206.000000  206.000000     206.000000
# mean   171.601942  161.451456     4.902913   64.621359       2.864078
# std     45.318459   16.988808     2.433564   73.558421       1.571382
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   33.000000       2.000000
# 50%    175.000000  165.000000     4.000000   44.000000       3.000000
# 75%    190.000000  172.000000     5.000000   66.750000       3.000000
# max    320.000000  195.000000    14.000000  610.000000      14.000000
#
#        OrderQuantity     Quantity      Repair     Delivery  PrintError  \
# count     206.000000   206.000000  206.000000   206.000000  206.000000
# mean      528.956311   574.305825    8.179612   559.199029    4.917476
# std       812.807992   891.308093    8.979205   866.214970   18.322796
# ...

# %%
#dataFrame is being saved as pkl files
dataFrame.to_pickle("../Data/WithRelationalTables/FabricWasteProduct.pkl")
