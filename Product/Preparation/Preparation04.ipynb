# %% [markdown]
# # Fourth Data Preparation Process
#
# In this notebook file, the dataset provided by the customer will be eddited for general purposes.
#
# The Color feature will be examined in depth.

# %%
#Library is being imported
import pandas as pd

# %%
#Library version is being printed
print('pandas Version: ' + pd.__version__)
# Out:
# pandas Version: 1.5.2

# %%
#A pandas dataframe named as dataFrame is being created by reading the data pkl file created last process
dataFrame = pd.read_pickle("../Data/WithRelationalTables/FabricWasteProduct.pkl")
dataFrame.head()
# Out:
#          Color  ProductDetail FabricCode  \
# 0        PINIE  KADIN T-SHIRT     2SP050
# 1     PFIRSICH  KADIN T-SHIRT     2SP050
# 2     HELLBLAU  KADIN T-SHIRT     2SP050
# 3   PETROLBLAU  KADIN T-SHIRT     2SP050
# 4  AUBERGINE 2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Quantity  Repair  \
# 0    150            4          35              3  ...       405      20
# 1    150            4          65              3  ...       414      22
# ...

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 0 to 208
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Color            206 non-null    object
#  1   ProductDetail    206 non-null    object
#  2   FabricCode       206 non-null    object
#  3   FabricDetail     206 non-null    object
#  4   IsManualProcess  206 non-null    bool
#  5   Weight           206 non-null    int64
#  6   Width            206 non-null    int64
#  7   ProductPart      206 non-null    int64
#  8   NotchLayer       206 non-null    int64
#  9   NotchQuantity    206 non-null    int64
#  10  OrderQuantity    206 non-null    int64
#  11  Quantity         206 non-null    int64
#  12  Repair           206 non-null    int64
#  13  Delivery         206 non-null    int64
#  14  PrintError       206 non-null    int64
#  15  SewingError      206 non-null    int64
#  16  FabricStain      206 non-null    int64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#            Weight       Width  ProductPart  NotchLayer  NotchQuantity  \
# count  206.000000  206.000000   206.000000  206.000000     206.000000
# mean   171.601942  161.451456     4.902913   64.621359       2.864078
# std     45.318459   16.988808     2.433564   73.558421       1.571382
# min    125.000000  120.000000     2.000000    0.000000       0.000000
# 25%    125.000000  150.000000     4.000000   33.000000       2.000000
# 50%    175.000000  165.000000     4.000000   44.000000       3.000000
# 75%    190.000000  172.000000     5.000000   66.750000       3.000000
# max    320.000000  195.000000    14.000000  610.000000      14.000000
#
#        OrderQuantity     Quantity      Repair     Delivery  PrintError  \
# count     206.000000   206.000000  206.000000   206.000000  206.000000
# mean      528.956311   574.305825    8.179612   559.199029    4.917476
# std       812.807992   891.308093    8.979205   866.214970   18.322796
# ...

# %%
#Number of unique values of each column are being printed
dataFrame.nunique()
# Out:
# Color               50
# ProductDetail       24
# FabricCode          19
# FabricDetail        19
# IsManualProcess      2
# Weight              11
# Width               12
# ProductPart         12
# NotchLayer          47
# NotchQuantity       10
# OrderQuantity       56
# Quantity           126
# Repair              30
# Delivery           152
# PrintError          29
# SewingError         31
# FabricStain          9
# FabricError         16
# EmbroideryError      7
# MeasureError         8
# SecondQuality       43
# dtype: int64

# %%
#Too many unique values for a categorical attribute in Color column
#In order to use this feature effectively, the values in the column will be processed

#Unique colors are being printed
dataFrame['Color'].unique()
# Out:
# array(['PINIE', 'PFIRSICH', 'HELLBLAU', 'PETROLBLAU', 'AUBERGINE 2',
#        'BLAUGRAU', 'LILA', 'SAFRAN', 'SCHWARZ', 'PUDER', 'NATURWEISS',
#        'MALVE', 'SILBERGRAU', 'MINT', 'BLASGELB   1', 'RETRO AOP',
#        'RINGEL AOP', 'JADEGRUN', 'WÄSCHE BLÜMCHEN AOP',
#        'WÄSCHE FLEUR AOP', 'WENDERINGEL', 'ORNAMENT AOP',
#        'LOTUS YOGA AOP', 'HEU', 'KORALLE', 'SALBEI', 'NACHTBLAU',
#        'LAVENDEL', 'ROSE MELANGE', 'GRAU(SNOW) MELANGE', 'TURKIS',
#        'GRAU(SNOW) MELANGE V2', 'AOP BLUMENWIESE', 'AOP UNTER WASSER',
#        'BUNGEE CORD', 'SUN DRIED TOMATO', 'BLUE WING TEAL', 'CHINA BLUE',
#        'DEEP BLACK', 'GREY MELANGE', 'BLACK/WHITE', 'NATURAL',
#        'SEA SPRAY', 'BLACK/WHITE FINE STRIPED', 'BLACK/SMOKED PEARL',
#        'MARSHMALLOW', 'WHITE', 'BLACK OLIVE', 'THYME', 'HIGH RISK RED'],
#       dtype=object)

# %%
#A pandas dataframe named as colorFrame is being created by reading the data from an excel file provided by customer
colorFrame = pd.read_excel('../Data/RawData/ColorCategory.xlsx')
colorFrame
# Out:
#                   Color CustomerDefinedCategory
# 0       AOP BLUMENWIESE              MixedColor
# 1      AOP UNTER WASSER              MixedColor
# 2             AUBERGINE                 Pinkish
# 3              BLASGELB               Yellowish
# 4              BLAUGRAU                DarkBlue
# 5    GRAU(SNOW) MELANGE                 Grayish
# 6              HELLBLAU                  Bluish
# 7                   HEU               Yellowish
# 8              JADEGRUN                Greenish
# 9               KORALLE               Orangeish
# 10                 LILA                Purplish
# 11       LOTUS YOGA AOP              MixedColor
# 12             LAVENDEL                Purplish
# 13                MALVE                 Pinkish
# 14                 MINT                Greenish
# 15           NATURWEISS               LightPink
# 16         ORNAMENT AOP              MixedColor
# 17            NACHTBLAU                DarkBlue
# 18                PINIE                Greenish
# ...

# %%
#dataFrame and colorFrame are being merged on Color column
mergedFrame = pd.merge(dataFrame, colorFrame, how='left', on=['Color'])
mergedFrame.head()
# Out:
#          Color  ProductDetail FabricCode  \
# 0        PINIE  KADIN T-SHIRT     2SP050
# 1     PFIRSICH  KADIN T-SHIRT     2SP050
# 2     HELLBLAU  KADIN T-SHIRT     2SP050
# 3   PETROLBLAU  KADIN T-SHIRT     2SP050
# 4  AUBERGINE 2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Repair  Delivery  \
# 0    150            4          35              3  ...      20       399
# 1    150            4          65              3  ...      22       411
# ...

# %%
#Rows without CustomerDefinedCategory information in colorFrame are being printed
mergedFrame[mergedFrame['CustomerDefinedCategory'].isnull()]
# Out:
#                         Color      ProductDetail FabricCode  \
# 4                 AUBERGINE 2      KADIN T-SHIRT     2SP050
# 12                AUBERGINE 2      KADIN T-SHIRT     2SP050
# 20                AUBERGINE 2      KADIN T-SHIRT     2SP050
# 25                AUBERGINE 2      KADIN T-SHIRT     2SP050
# 29                AUBERGINE 2     KADIN PANTOLON     2SP050
# 37               BLASGELB   1      KADIN T-SHIRT     2SP021
# 42               BLASGELB   1      KADIN T-SHIRT     2SP021
# 47               BLASGELB   1      KADIN T-SHIRT     2SP021
# 77                AUBERGINE 2     KADIN PANTOLON     2SP061
# 80                AUBERGINE 2     KADIN PANTOLON     2SP061
# 83                AUBERGINE 2       KADIN ELBISE     2SP061
# 116               AUBERGINE 2     KADIN PANTOLON     2SP061
# 148     GRAU(SNOW) MELANGE V2  KIZ COCUK T-SHIRT     2SP033
# 158               AUBERGINE 2      COCUK T-SHIRT     2SP061
# 160               AUBERGINE 2     COCUK PANTOLON     2SP061
# ...

# %%
#In this section, it should be examined 
#whether the colors that are not in the Color Frame resemble one of the colors in the Color Frame

#Unique color values in colorFrame are being printed
colorFrame['Color'].unique()
# Out:
# array(['AOP BLUMENWIESE', 'AOP UNTER WASSER', 'AUBERGINE', 'BLASGELB',
#        'BLAUGRAU', 'GRAU(SNOW) MELANGE', 'HELLBLAU', 'HEU', 'JADEGRUN',
#        'KORALLE', 'LILA', 'LOTUS YOGA AOP', 'LAVENDEL', 'MALVE', 'MINT',
#        'NATURWEISS', 'ORNAMENT AOP', 'NACHTBLAU', 'PINIE', 'PFIRSICH',
#        'PETROLBLAU', 'PUDER', 'RETRO AOP', 'RINGEL AOP', 'ROSE MELANGE',
#        'SAFRAN', 'SCHWARZ', 'SILBERGRAU', 'SALBEI', 'WÄSCHE BLÜMCHEN AOP',
#        'WÄSCHE FLEUR AOP', 'WENDERINGEL', 'TURKIS', 'BUNGEE CORD',
#        'SUN DRIED TOMATO', 'BLUE WING TEAL', 'CHINA BLUE', 'DEEP BLACK',
#        'GREY MELANGE', 'BLACK/WHITE', 'NATURAL', 'SEA SPRAY',
#        'BLACK/SMOKED PEARL', 'MARSHMALLOW', 'WHITE', 'BLACK OLIVE',
#        'THYME', 'HIGH RISK RED'], dtype=object)

# %%
#Processes are being performed according to the color values of the rows in the mergedFrame 
#whose CustomerDefinedCategory value is null and the unique color values in the colorFrame

#AUBERGINE 2 color values in dataFrame are being converted to AUBERGINE color value in colorFrame
dataFrame.loc[dataFrame['Color'] == 'AUBERGINE 2', 'Color'] =  'AUBERGINE'

#BLASGELB 1 color values in dataFrame are being converted to BLASGELB color value in colorFrame
dataFrame.loc[dataFrame['Color'] == 'BLASGELB   1', 'Color'] =  'BLASGELB'

#GRAU(SNOW) MELANGE V2 color values in dataFrame are being converted to GRAU(SNOW) MELANGE color value in colorFrame
dataFrame.loc[dataFrame['Color'] == 'GRAU(SNOW) MELANGE V2', 'Color'] =  'GRAU(SNOW) MELANGE'

#BLACK/WHITE FINE STRIPED color values in dataFrame are being converted to BLACK/WHITE color value in colorFrame
dataFrame.loc[dataFrame['Color'] == 'BLACK/WHITE FINE STRIPED', 'Color'] =  'BLACK/WHITE'

dataFrame.head()
# Out:
#         Color  ProductDetail FabricCode  \
# 0       PINIE  KADIN T-SHIRT     2SP050
# 1    PFIRSICH  KADIN T-SHIRT     2SP050
# 2    HELLBLAU  KADIN T-SHIRT     2SP050
# 3  PETROLBLAU  KADIN T-SHIRT     2SP050
# 4   AUBERGINE  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Quantity  Repair  \
# 0    150            4          35              3  ...       405      20
# 1    150            4          65              3  ...       414      22
# ...

# %%
#dataFrame and colorFrame are being merged on Color column
mergedFrame = pd.merge(dataFrame, colorFrame, how='left', on=['Color'])
mergedFrame.head()
# Out:
#         Color  ProductDetail FabricCode  \
# 0       PINIE  KADIN T-SHIRT     2SP050
# 1    PFIRSICH  KADIN T-SHIRT     2SP050
# 2    HELLBLAU  KADIN T-SHIRT     2SP050
# 3  PETROLBLAU  KADIN T-SHIRT     2SP050
# 4   AUBERGINE  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Repair  Delivery  \
# 0    150            4          35              3  ...      20       399
# 1    150            4          65              3  ...      22       411
# ...

# %%
#Rows without CustomerDefinedCategory information in colorFrame are being printed
mergedFrame[mergedFrame['CustomerDefinedCategory'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Color, ProductDetail, FabricCode, FabricDetail, IsManualProcess, Weight, Width, ProductPart, NotchLayer, NotchQuantity, OrderQuantity, Quantity, Repair, Delivery, PrintError, SewingError, FabricStain, FabricError, EmbroideryError, MeasureError, SecondQuality, CustomerDefinedCategory]
# Index: []
#
# [0 rows x 22 columns]

# %%
#Now that the Color columns in the dataFrame and colorFrame are properly matched, new attributes can be added to the colorFrame

#Unique color values in colorFrame are being printed
colorFrame['Color'].unique()
# Out:
# array(['AOP BLUMENWIESE', 'AOP UNTER WASSER', 'AUBERGINE', 'BLASGELB',
#        'BLAUGRAU', 'GRAU(SNOW) MELANGE', 'HELLBLAU', 'HEU', 'JADEGRUN',
#        'KORALLE', 'LILA', 'LOTUS YOGA AOP', 'LAVENDEL', 'MALVE', 'MINT',
#        'NATURWEISS', 'ORNAMENT AOP', 'NACHTBLAU', 'PINIE', 'PFIRSICH',
#        'PETROLBLAU', 'PUDER', 'RETRO AOP', 'RINGEL AOP', 'ROSE MELANGE',
#        'SAFRAN', 'SCHWARZ', 'SILBERGRAU', 'SALBEI', 'WÄSCHE BLÜMCHEN AOP',
#        'WÄSCHE FLEUR AOP', 'WENDERINGEL', 'TURKIS', 'BUNGEE CORD',
#        'SUN DRIED TOMATO', 'BLUE WING TEAL', 'CHINA BLUE', 'DEEP BLACK',
#        'GREY MELANGE', 'BLACK/WHITE', 'NATURAL', 'SEA SPRAY',
#        'BLACK/SMOKED PEARL', 'MARSHMALLOW', 'WHITE', 'BLACK OLIVE',
#        'THYME', 'HIGH RISK RED'], dtype=object)

# %%
#featureFrame that contains the detailed information of the values in the dataFrame Color column is being created

#ColorCode and ColorType is being created manually by examining the color names
#ColorCode column is in RGB format and ColorCodes of rows containing multi color are assigned as [-1, -1, -1]
#With this method, it is being stated that the ColorCode is meaningless for the products that contain multi color
#In this case it can be seen that the ColorCode attribute must be used with ColorType attribute but ColorType can be used alone
featureFrame = pd.DataFrame({
                            'Color' : colorFrame['Color'].unique(),
                            'ColorCode' : [[-1, -1, -1], [-1, -1, -1], [72, 50, 72], [255, 255, 167],
                                           [106, 90, 205], [250, 250, 250], [173, 216, 230], [218, 205, 129], [94, 251, 110],
                                           [255, 127, 80], [200, 162, 200], [-1, -1, -1], [150, 123, 182], [224, 176, 255], 
                                                                                                               [62,180,137],
                                           [238, 235, 227], [-1, -1, -1], [25, 25, 112], [42, 47, 35], [255, 229, 180],
                                           [0, 95, 106], [255, 178, 208], [-1, -1, -1], [-1, -1, -1], [255, 0 ,127], 
                                           [244, 196, 48], [0, 0, 0], [193, 183, 176], [138, 154, 91], [-1, -1, -1],
                                           [-1, -1, -1], [-1, -1, -1], [48, 213, 200], [105, 97, 86],
                                           [105, 43, 43], [44, 64, 83], [54, 81, 148], [5, 2, 3],
                                           [204, 202, 201], [-1, -1, -1], [229, 211, 191], [210, 237, 218],
                                           [-1, -1, -1], [249, 245, 236], [255, 255, 255], [59, 60,54],
                                           [80, 87, 76], [199, 31, 45]
                                          ],
                            'ColorType' :['AOP', 'AOP', 'SC', 'SC', 'SC', 'M', 'SC', 'SC', 'SC', 'SC', 'SC', 'AOP', 
                                          'SC', 'SC', 'SC', 'SC', 'AOP', 'SC', 'SC', 'SC', 'SC', 'SC', 'AOP', 'AOP',
                                          'M', 'SC', 'SC', 'SC', 'SC', 'AOP', 'AOP', 'S', 'SC', 'SC', 'SC', 'SC',
                                          'SC', 'SC', 'M', 'S', 'SC', 'SC', 'S', 'SC', 'SC', 'SC', 'SC', 'SC']
                            })
featureFrame
# Out:
#                   Color        ColorCode ColorType
# 0       AOP BLUMENWIESE     [-1, -1, -1]       AOP
# 1      AOP UNTER WASSER     [-1, -1, -1]       AOP
# 2             AUBERGINE     [72, 50, 72]        SC
# 3              BLASGELB  [255, 255, 167]        SC
# 4              BLAUGRAU   [106, 90, 205]        SC
# 5    GRAU(SNOW) MELANGE  [250, 250, 250]         M
# 6              HELLBLAU  [173, 216, 230]        SC
# 7                   HEU  [218, 205, 129]        SC
# 8              JADEGRUN   [94, 251, 110]        SC
# 9               KORALLE   [255, 127, 80]        SC
# 10                 LILA  [200, 162, 200]        SC
# 11       LOTUS YOGA AOP     [-1, -1, -1]       AOP
# 12             LAVENDEL  [150, 123, 182]        SC
# 13                MALVE  [224, 176, 255]        SC
# 14                 MINT   [62, 180, 137]        SC
# 15           NATURWEISS  [238, 235, 227]        SC
# 16         ORNAMENT AOP     [-1, -1, -1]       AOP
# ...

# %%
#typeFrame that contains the full name information of the categories in the featureFrame colorType column is being created
typeFrame = pd.DataFrame({
                                'ColorType' : ['AOP', 'SC', 'M', 'S'],
                                'ColorTypeName' :['All Over Print', 'Solid Color', 'Melange', 'Stripe']
                                })
typeFrame
# Out:
#   ColorType   ColorTypeName
# 0       AOP  All Over Print
# 1        SC     Solid Color
# 2         M         Melange
# 3         S          Stripe

# %%
#featureFrame and typeFrame are being merged on ColorType column
featureFrame = pd.merge(featureFrame, typeFrame, how='left', on=['ColorType'])
featureFrame
# Out:
#                   Color        ColorCode ColorType   ColorTypeName
# 0       AOP BLUMENWIESE     [-1, -1, -1]       AOP  All Over Print
# 1      AOP UNTER WASSER     [-1, -1, -1]       AOP  All Over Print
# 2             AUBERGINE     [72, 50, 72]        SC     Solid Color
# 3              BLASGELB  [255, 255, 167]        SC     Solid Color
# 4              BLAUGRAU   [106, 90, 205]        SC     Solid Color
# 5    GRAU(SNOW) MELANGE  [250, 250, 250]         M         Melange
# 6              HELLBLAU  [173, 216, 230]        SC     Solid Color
# 7                   HEU  [218, 205, 129]        SC     Solid Color
# 8              JADEGRUN   [94, 251, 110]        SC     Solid Color
# 9               KORALLE   [255, 127, 80]        SC     Solid Color
# 10                 LILA  [200, 162, 200]        SC     Solid Color
# 11       LOTUS YOGA AOP     [-1, -1, -1]       AOP  All Over Print
# 12             LAVENDEL  [150, 123, 182]        SC     Solid Color
# ...

# %%
#featureFrame and colorFrame are being merged on Color column
colorFrame =  pd.merge(featureFrame, colorFrame, how='left', on=['Color'])
colorFrame
# Out:
#                   Color        ColorCode ColorType   ColorTypeName  \
# 0       AOP BLUMENWIESE     [-1, -1, -1]       AOP  All Over Print
# 1      AOP UNTER WASSER     [-1, -1, -1]       AOP  All Over Print
# 2             AUBERGINE     [72, 50, 72]        SC     Solid Color
# 3              BLASGELB  [255, 255, 167]        SC     Solid Color
# 4              BLAUGRAU   [106, 90, 205]        SC     Solid Color
# 5    GRAU(SNOW) MELANGE  [250, 250, 250]         M         Melange
# 6              HELLBLAU  [173, 216, 230]        SC     Solid Color
# 7                   HEU  [218, 205, 129]        SC     Solid Color
# 8              JADEGRUN   [94, 251, 110]        SC     Solid Color
# 9               KORALLE   [255, 127, 80]        SC     Solid Color
# 10                 LILA  [200, 162, 200]        SC     Solid Color
# 11       LOTUS YOGA AOP     [-1, -1, -1]       AOP  All Over Print
# 12             LAVENDEL  [150, 123, 182]        SC     Solid Color
# ...

# %%
#ColorCodes are being splitted into Red, Green, Blue values
colorFrame['Red'] =  colorFrame['ColorCode'].apply(lambda x : x[0])
colorFrame['Green'] =  colorFrame['ColorCode'].apply(lambda x : x[1])
colorFrame['Blue'] =  colorFrame['ColorCode'].apply(lambda x : x[2])
colorFrame
# Out:
#                   Color        ColorCode ColorType   ColorTypeName  \
# 0       AOP BLUMENWIESE     [-1, -1, -1]       AOP  All Over Print
# 1      AOP UNTER WASSER     [-1, -1, -1]       AOP  All Over Print
# 2             AUBERGINE     [72, 50, 72]        SC     Solid Color
# 3              BLASGELB  [255, 255, 167]        SC     Solid Color
# 4              BLAUGRAU   [106, 90, 205]        SC     Solid Color
# 5    GRAU(SNOW) MELANGE  [250, 250, 250]         M         Melange
# 6              HELLBLAU  [173, 216, 230]        SC     Solid Color
# 7                   HEU  [218, 205, 129]        SC     Solid Color
# 8              JADEGRUN   [94, 251, 110]        SC     Solid Color
# 9               KORALLE   [255, 127, 80]        SC     Solid Color
# 10                 LILA  [200, 162, 200]        SC     Solid Color
# 11       LOTUS YOGA AOP     [-1, -1, -1]       AOP  All Over Print
# 12             LAVENDEL  [150, 123, 182]        SC     Solid Color
# ...

# %%
#Since all information about Colors is kept in the colorFrame,
#it will bi sufficient to keep foreign key values of Colors representing the colorFrame data in the dataFrame

#dataFrame Color column is being recreated as colorFrame indexes
dataFrame['Color'] = dataFrame['Color'].apply(lambda x : colorFrame.index[colorFrame['Color'] == x].tolist()[0])
dataFrame.head()
# Out:
#    Color  ProductDetail FabricCode  \
# 0     18  KADIN T-SHIRT     2SP050
# 1     19  KADIN T-SHIRT     2SP050
# 2      6  KADIN T-SHIRT     2SP050
# 3     20  KADIN T-SHIRT     2SP050
# 4      2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Quantity  Repair  \
# 0    150            4          35              3  ...       405      20
# 1    150            4          65              3  ...       414      22
# ...

# %%
#Color column is being renamed as ColorID
dataFrame.rename(columns = {'Color' : 'ColorID'}, inplace = True)
dataFrame.head()
# Out:
#    ColorID  ProductDetail FabricCode  \
# 0       18  KADIN T-SHIRT     2SP050
# 1       19  KADIN T-SHIRT     2SP050
# 2        6  KADIN T-SHIRT     2SP050
# 3       20  KADIN T-SHIRT     2SP050
# 4        2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  IsManualProcess  Weight  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...            False     125
#
#    Width  ProductPart  NotchLayer  NotchQuantity  ...  Quantity  Repair  \
# 0    150            4          35              3  ...       405      20
# 1    150            4          65              3  ...       414      22
# ...

# %%
#Information of dataframe is being printed
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206 entries, 0 to 208
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ColorID          206 non-null    int64
#  1   ProductDetail    206 non-null    object
#  2   FabricCode       206 non-null    object
#  3   FabricDetail     206 non-null    object
#  4   IsManualProcess  206 non-null    bool
#  5   Weight           206 non-null    int64
#  6   Width            206 non-null    int64
#  7   ProductPart      206 non-null    int64
#  8   NotchLayer       206 non-null    int64
#  9   NotchQuantity    206 non-null    int64
#  10  OrderQuantity    206 non-null    int64
#  11  Quantity         206 non-null    int64
#  12  Repair           206 non-null    int64
#  13  Delivery         206 non-null    int64
#  14  PrintError       206 non-null    int64
#  15  SewingError      206 non-null    int64
#  16  FabricStain      206 non-null    int64
# ...

# %%
#Statistical information of dataframe is being printed
dataFrame.describe()
# Out:
#           ColorID      Weight       Width  ProductPart  NotchLayer  \
# count  206.000000  206.000000  206.000000   206.000000  206.000000
# mean    16.796117  171.601942  161.451456     4.902913   64.621359
# std     11.881413   45.318459   16.988808     2.433564   73.558421
# min      0.000000  125.000000  120.000000     2.000000    0.000000
# 25%      5.000000  125.000000  150.000000     4.000000   33.000000
# 50%     16.000000  175.000000  165.000000     4.000000   44.000000
# 75%     26.000000  190.000000  172.000000     5.000000   66.750000
# max     47.000000  320.000000  195.000000    14.000000  610.000000
#
#        NotchQuantity  OrderQuantity     Quantity      Repair     Delivery  \
# count     206.000000     206.000000   206.000000  206.000000   206.000000
# mean        2.864078     528.956311   574.305825    8.179612   559.199029
# std         1.571382     812.807992   891.308093    8.979205   866.214970
# ...

# %%
#Information of colorFrame is being printed
colorFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Color                    48 non-null     object
#  1   ColorCode                48 non-null     object
#  2   ColorType                48 non-null     object
#  3   ColorTypeName            48 non-null     object
#  4   CustomerDefinedCategory  48 non-null     object
#  5   Red                      48 non-null     int64
#  6   Green                    48 non-null     int64
#  7   Blue                     48 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.4+ KB

# %%
#Statistical information of colorFrame is being printed
colorFrame.describe()
# Out:
#               Red       Green        Blue
# count   48.000000   48.000000   48.000000
# mean   115.395833  109.250000  107.395833
# std    101.734477   95.714669   89.051919
# min     -1.000000   -1.000000   -1.000000
# 25%      0.000000    0.000000    2.250000
# 50%     99.500000   92.500000   98.500000
# 75%    219.500000  202.750000  193.250000
# max    255.000000  255.000000  255.000000

# %%
#dataFrame and relational colorFrame are being saved as pkl files
dataFrame.to_pickle("../Data/WithRelationalTables/FabricWasteColor.pkl")
colorFrame.to_pickle("../Data/WithRelationalTables/Color.pkl")
