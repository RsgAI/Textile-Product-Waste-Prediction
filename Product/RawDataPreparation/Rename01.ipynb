# %% [markdown]
# # Rename Column Process

# %%
#Library is being imported
import pandas as pd

# %%
#Library version is being printed
print('pandas Version: ' + pd.__version__)
# Out:
# pandas Version: 1.5.2

# %%
#A pandas dataframe named as dataFrame is being created by reading the data from an excel file
dataFrame = pd.read_excel('../Data/RawData/FabricWasteInitial.xlsx')
dataFrame
# Out:
#      Sipariş No                        Malzeme Açıklaması            Renk  \
# 0          4982                M6030 JERSEY SHIRT LANGARM           PINIE
# 1          4982                M6030 JERSEY SHIRT LANGARM        PFIRSICH
# 2          4982                M6030 JERSEY SHIRT LANGARM        HELLBLAU
# 3          4982                M6030 JERSEY SHIRT LANGARM      PETROLBLAU
# 4          4982                M6030 JERSEY SHIRT LANGARM     AUBERGINE 2
# ..          ...                                       ...             ...
# 204        4828        B1093 [BMW] ZIP HOODIE  MLAR DAMEN      DEEP BLACK
# 205        4828  B1094 [BMW] 02 MEN'S TSHIRT SPIRIT OF GS     BLACK OLIVE
# 206        4828         B1095 [BMW] 03 TSHIRT JUMP OLIVE            THYME
# 207        4828     B1096 [BMW] 05 TSHIRT GLORIOUS 4 BLAU  BLUE WING TEAL
# 208        4828       B1097 [BMW] 12 TSHIRT GS ROT DAMEN    HIGH RISK RED
#
#     Türkçe Açıklama Kumaş Kodu  \
# 0     KADIN T-SHIRT     2SP050
# ...

# %%
#Colums of dataFrame are being printed
dataFrame.columns
# Out:
# Index(['Sipariş No', 'Malzeme Açıklaması', 'Renk', 'Türkçe Açıklama',
#        'Kumaş Kodu', 'Kumaş Açıklaması', 'Gramaj', 'Kumaş Eni',
#        'Üründeki Parça Sayısı', 'Pastal Kat Adedi', 'Pastal Sayısı',
#        'Sipariş Adedi', 'Fireli Planlanan Kesim Adedi', 'Kesim Adedi',
#        'Baskı / Nakış', 'Tamir Adedi', 'Yükleme Adedi', 'Eksik Kesim Nedeni',
#        'Ürün 2. Kalite Ayrılma Ana Nedeni', 'Baskı', 'Dikim', 'Leke', 'Kumaş',
#        'Nakış', 'Ölçü', 'İkinci Kalite Adedi', 'Açıklama'],
#       dtype='object')

# %%
#Since column names are in Turkish, the names are being translated into English manually
dataFrame.columns = ['OrderNo', 'Product', 'Color', 'ProductDetail', 'FabricCode', 'FabricDetail', 'Weight', 'Width',
                     'ProductPart', 'NotchLayer', 'NotchQuantity', 'OrderQuantity', 'Planned', 'Quantity', 'Print',
                    'Repair', 'Delivery', 'Reason1', 'Reason2', 'PrintError', 'SewingError', 'FabricStain', 'FabricError',
                     'EmbroideryError', 'MeasureError', 'SecondQuality', 'Comment']
dataFrame.columns
# Out:
# Index(['OrderNo', 'Product', 'Color', 'ProductDetail', 'FabricCode',
#        'FabricDetail', 'Weight', 'Width', 'ProductPart', 'NotchLayer',
#        'NotchQuantity', 'OrderQuantity', 'Planned', 'Quantity', 'Print',
#        'Repair', 'Delivery', 'Reason1', 'Reason2', 'PrintError', 'SewingError',
#        'FabricStain', 'FabricError', 'EmbroideryError', 'MeasureError',
#        'SecondQuality', 'Comment'],
#       dtype='object')

# %%
#First 5 rows of dataFrame
dataFrame.head()
# Out:
#    OrderNo                     Product        Color  ProductDetail FabricCode  \
# 0     4982  M6030 JERSEY SHIRT LANGARM        PINIE  KADIN T-SHIRT     2SP050
# 1     4982  M6030 JERSEY SHIRT LANGARM     PFIRSICH  KADIN T-SHIRT     2SP050
# 2     4982  M6030 JERSEY SHIRT LANGARM     HELLBLAU  KADIN T-SHIRT     2SP050
# 3     4982  M6030 JERSEY SHIRT LANGARM   PETROLBLAU  KADIN T-SHIRT     2SP050
# 4     4982  M6030 JERSEY SHIRT LANGARM  AUBERGINE 2  KADIN T-SHIRT     2SP050
#
#                                         FabricDetail  Weight Width  \
# 0  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 1  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 2  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 3  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
# 4  NE 50/1 PNY 20DE - SUPREM A.EN 32 28 125 G/M2 ...     125   150
#
#    ProductPart NotchLayer  ...        Reason1            Reason2  PrintError  \
# ...

# %%
#dataFrame is being saved as excel
dataFrame.to_excel('../Data/RawData/FabricWaste.xlsx', index = False)
