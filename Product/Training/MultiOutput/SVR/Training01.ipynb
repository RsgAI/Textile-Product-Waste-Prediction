# %% [markdown]
# # Support Vector Regression
#
# In this notebook file, a Support Vector Regression model will be trained with FabricWaste data for predict All Output Rates

# %%
#Libraries are being imported
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlibVersion

from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import __version__ as sklearnVersion

from joblib import dump, __version__ as joblibVersion

# %%
#Library versions are being printed
print('numpy Version: ' + np.__version__)
print('pandas Version: ' + pd.__version__)
print('matplotlib Version: ' + matplotlibVersion)
print('sklearn Version: ' + sklearnVersion)
print('joblib Version: ' + joblibVersion)
# Out:
# numpy Version: 1.23.5
# pandas Version: 1.5.2
# matplotlib Version: 3.6.2
# sklearn Version: 1.2.0
# joblib Version: 1.1.1

# %%
#Constant is being defined
MODEL_NAME = 'SVR'

# %%
#Function to draw Chart
def DrawChart(title, value, predicted):
    plt.figure(figsize = (12, 6))
    plt.title(title)
    plt.scatter(value, predicted)
    plt.plot(value, value, 'r')
    plt.legend(['Predictions', 'LineOfRealValues'])

# %%
#trainingFrame is being created by reading a pkl file
trainingFrame = pd.read_pickle("../../../Data/DataSplit/Training.pkl")
trainingFrame
# Out:
#           PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0   -2.159842  0.903073 -0.903965 -0.494504 -1.292695  0.619725 -0.410849
# 1    0.162054 -1.141753 -0.219059  1.554529  1.432512 -0.847058 -0.229250
# 2   -0.249417 -2.523880  0.002460 -2.579382  0.628535  1.531744  0.705912
# 3   -0.993506 -0.761118  0.053950 -1.878065 -1.164023 -1.238222 -0.260116
# 4    4.394100  4.620156  6.910180  0.250664  2.236256 -1.335311  1.639115
# ..        ...       ...       ...       ...       ...       ...       ...
# 145 -0.985567  3.733304 -3.353928  0.286889  3.159942 -0.564599 -2.566718
# 146 -0.106127  2.282926 -2.429306 -0.651671  3.116188 -1.764173 -1.643339
# 147 -1.707846  0.246973 -0.244842 -1.982393 -1.471280  0.214617 -1.076689
# 148 -1.807489 -1.112117  0.789260  0.397510 -1.555010 -2.839794 -1.167443
# 149 -1.701620  0.471598 -0.708846 -1.057225 -0.672278  0.099186 -0.264731
#
#           PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0    1.097258  0.081156  0.803563  ...           6            1            0
# 1    0.049316  3.855226  1.932691  ...           0           19            1
# 2    0.202348 -1.614852 -0.546322  ...           0            5            0
# 3   -0.716803 -1.282542  1.161412  ...           0            1            0
# 4    1.140519 -2.365281  4.222803  ...          17           12            1
# ..        ...       ...       ...  ...         ...          ...          ...
# 145  0.468873 -0.836925 -0.633818  ...          15            1            0
# 146 -1.005481  0.105907 -1.034012  ...           4            0            0
# 147 -0.492724 -0.296742  0.468674  ...           0            4            2
# 148  0.011566  0.636225 -1.302368  ...           0           13            3
# 149 -0.287430  0.556480  0.302552  ...           0            4            0
#
#      FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0              0                0             0              7
# 1              5                0             1             26
# 2              0                0             0              5
# 3              0                0             0              1
# 4              0                0             0             30
# ..           ...              ...           ...            ...
# 145            1                0             0             16
# 146            0                0             0              4
# 147            2                0             0              8
# 148            5                0             3             23
# 149            0                0             0              4
#
#      CalculatedSecondQuality  Defect  OrderQuantity
# 0                          7      15            380
# 1                         26      33            295
# 2                          5      21            310
# 3                          1       6            370
# 4                         30      44           1645
# ..                       ...     ...            ...
# 145                       17      19            300
# 146                        4       7            250
# 147                        8      25            375
# 148                       24      30            550
# 149                        4      12            380
#
# [150 rows x 41 columns]

# %%
#Information of trainingFrame is being printed
trainingFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      150 non-null    float64
#  1   PC1                      150 non-null    float64
#  2   PC2                      150 non-null    float64
#  3   PC3                      150 non-null    float64
#  4   PC4                      150 non-null    float64
#  5   PC5                      150 non-null    float64
#  6   PC6                      150 non-null    float64
#  7   PC7                      150 non-null    float64
#  8   PC8                      150 non-null    float64
#  9   PC9                      150 non-null    float64
#  10  PC10                     150 non-null    float64
#  11  PC11                     150 non-null    float64
#  12  PC12                     150 non-null    float64
#  13  PC13                     150 non-null    float64
#  14  PC14                     150 non-null    float64
#  15  PC15                     150 non-null    float64
#  16  PC16                     150 non-null    float64
#  17  PC17                     150 non-null    float64
#  18  PC18                     150 non-null    float64
#  19  PC19                     150 non-null    float64
#  20  PC20                     150 non-null    float64
#  21  PC21                     150 non-null    float64
#  22  PC22                     150 non-null    float64
#  23  PrintErrorRate           150 non-null    float64
#  24  SewingErrorRate          150 non-null    float64
#  25  FabricStainRate          150 non-null    float64
#  26  FabricErrorRate          150 non-null    float64
#  27  EmbroideryErrorRate      150 non-null    float64
#  28  MeasureErrorRate         150 non-null    float64
#  29  SecondQualityRate        150 non-null    float64
#  30  DefectRate               150 non-null    float64
#  31  PrintError               150 non-null    int64
#  32  SewingError              150 non-null    int64
#  33  FabricStain              150 non-null    int64
#  34  FabricError              150 non-null    int64
#  35  EmbroideryError          150 non-null    int64
#  36  MeasureError             150 non-null    int64
#  37  SecondQuality            150 non-null    int64
#  38  CalculatedSecondQuality  150 non-null    int64
#  39  Defect                   150 non-null    int64
#  40  OrderQuantity            150 non-null    int64
# dtypes: float64(31), int64(10)
# memory usage: 48.2 KB

# %%
#Statistical information of trainingFrame part to use is being printed
trainingFrame.loc[:, : 'DefectRate'].describe()
# Out:
#                 PC0           PC1           PC2           PC3           PC4  \
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean   2.368476e-17 -1.125026e-16 -1.065814e-16 -2.368476e-17 -2.368476e-17
# std    2.742575e+00  2.575942e+00  2.354006e+00  2.106912e+00  1.869427e+00
# min   -2.593435e+00 -5.356644e+00 -5.332553e+00 -3.363834e+00 -3.622670e+00
# 25%   -1.663962e+00 -1.592389e+00 -1.189392e+00 -1.525014e+00 -1.378872e+00
# 50%   -4.565722e-01  3.784231e-01 -2.626697e-01 -5.582300e-01 -6.168971e-01
# 75%    3.168803e-01  1.385057e+00  7.821502e-01  1.150648e+00  1.266148e+00
# max    1.304181e+01  5.395295e+00  1.014250e+01  6.680256e+00  5.805823e+00
#
#                 PC5           PC6           PC7           PC8           PC9  \
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean   1.539509e-16  4.736952e-17 -1.894781e-16  4.144833e-17 -1.465494e-16
# std    1.709458e+00  1.562710e+00  1.494945e+00  1.336939e+00  1.319240e+00
# min   -4.180609e+00 -3.077161e+00 -3.586945e+00 -3.568800e+00 -4.299588e+00
# 25%   -1.195458e+00 -6.770874e-01 -8.965826e-01 -8.102841e-01 -8.504962e-01
# 50%    1.307688e-01 -2.511817e-01  3.859758e-02 -1.363654e-01  1.792644e-03
# 75%    1.173204e+00  4.458845e-01  9.306250e-01  5.667936e-01  6.908789e-01
# max    4.858948e+00  5.377690e+00  5.203551e+00  3.855226e+00  5.227225e+00
#
#        ...          PC21          PC22  PrintErrorRate  SewingErrorRate  \
# count  ...  1.500000e+02  1.500000e+02      150.000000       150.000000
# mean   ... -5.921189e-17 -1.125026e-16        0.004084         0.013615
# std    ...  9.204159e-01  9.104180e-01        0.008244         0.012301
# min    ... -2.169231e+00 -3.550595e+00        0.000000         0.000000
# 25%    ... -5.420482e-01 -3.440578e-01        0.000000         0.004617
# 50%    ... -4.370206e-02  1.117789e-01        0.000000         0.009662
# 75%    ...  4.777897e-01  5.891056e-01        0.004640         0.017848
# max    ...  2.954614e+00  4.063812e+00        0.044643         0.058282
#
#        FabricStainRate  FabricErrorRate  EmbroideryErrorRate  \
# count       150.000000       150.000000           150.000000
# mean          0.000712         0.004679             0.000547
# std           0.001953         0.007235             0.002289
# min           0.000000         0.000000             0.000000
# 25%           0.000000         0.000000             0.000000
# 50%           0.000000         0.002206             0.000000
# 75%           0.000000         0.006057             0.000000
# max           0.013158         0.041667             0.015060
#
#        MeasureErrorRate  SecondQualityRate  DefectRate
# count        150.000000         150.000000  150.000000
# mean           0.000825           0.024462    0.045132
# std            0.004019           0.017073    0.023845
# min            0.000000           0.002262    0.009091
# 25%            0.000000           0.012884    0.028450
# 50%            0.000000           0.020761    0.039438
# 75%            0.000000           0.030945    0.059436
# max            0.044643           0.079755    0.118812
#
# [8 rows x 31 columns]

# %%
#The outputName list is being created by getting the column names of the output features in order
outputName = trainingFrame.loc[:, 'PrintErrorRate' : 'DefectRate'].columns.tolist()
outputName
# Out:
# ['PrintErrorRate',
#  'SewingErrorRate',
#  'FabricStainRate',
#  'FabricErrorRate',
#  'EmbroideryErrorRate',
#  'MeasureErrorRate',
#  'SecondQualityRate',
#  'DefectRate']

# %%
#trainingX is being created with input features of trainingFrame
trainingX = trainingFrame.loc[:, : 'PC22'].values
trainingX.shape
# Out:
# (150, 23)

# %%
#trainingY is being created with Error Rate features of trainingFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
trainingY = trainingFrame.loc[:, 'PrintErrorRate' : 'DefectRate'].values * 100
trainingY.shape
# Out:
# (150, 8)

# %%
#An SVR model is being trained
regressor = MultiOutputRegressor(SVR()).fit(trainingX, trainingY)
predictions = regressor.predict(trainingX)
predictions.shape
# Out:
# (150, 8)

# %%
#resultFrame based on predictions and real values is being created
resultDict = {'Model' : [], 'Data' : [], 'ColumName' : [], 'MeanAbsoluteError' : [],
              'MeanSquaredError' : [], 'SqrtMeanSquaredError' : []}
for i in range(predictions.shape[1]):
    resultDict['Model'].append(MODEL_NAME)
    resultDict['Data'].append('Training')
    resultDict['ColumName'].append(outputName[i])
    resultDict['MeanAbsoluteError'].append(mean_absolute_error(trainingY[:,i], predictions[:,i]))
    resultDict['MeanSquaredError'].append(mean_squared_error(trainingY[:,i], predictions[:,i]))
    resultDict['SqrtMeanSquaredError'].append(np.sqrt(mean_squared_error(trainingY[:,i], predictions[:,i])))
    
resultDict['Model'].append(MODEL_NAME)
resultDict['Data'].append('Training')
resultDict['ColumName'].append('Average')
resultDict['MeanAbsoluteError'].append(np.mean(resultDict['MeanAbsoluteError']))
resultDict['MeanSquaredError'].append(np.mean(resultDict['MeanSquaredError']))
resultDict['SqrtMeanSquaredError'].append(np.mean(resultDict['SqrtMeanSquaredError']))

resultFrame = pd.DataFrame(resultDict)
resultFrame
# Out:
#   Model      Data            ColumName  MeanAbsoluteError  MeanSquaredError  \
# 0   SVR  Training       PrintErrorRate           0.305200          0.500667
# 1   SVR  Training      SewingErrorRate           0.638757          1.005050
# 2   SVR  Training      FabricStainRate           0.110003          0.029252
# 3   SVR  Training      FabricErrorRate           0.301352          0.363148
# 4   SVR  Training  EmbroideryErrorRate           0.110171          0.044925
# 5   SVR  Training     MeasureErrorRate           0.134291          0.140288
# 6   SVR  Training    SecondQualityRate           0.837695          1.835184
# 7   SVR  Training           DefectRate           1.333833          3.429191
# 8   SVR  Training              Average           0.471413          0.918463
#
#    SqrtMeanSquaredError
# 0              0.707578
# 1              1.002522
# 2              0.171031
# 3              0.602618
# 4              0.211955
# 5              0.374551
# 6              1.354690
# 7              1.851807
# 8              0.784594

# %%
#validationFrame is being created by reading a pkl file
validationFrame = pd.read_pickle("../../../Data/DataSplit/Validation.pkl")
validationFrame
# Out:
#          PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0  -1.601754 -0.408275 -0.788667 -1.142983 -1.512157 -0.353603 -0.338590
# 1   0.025378  0.418853  0.034701  4.251172 -0.396508  3.287433  1.986794
# 2  -0.697826  1.466843 -0.721390  3.081282 -0.023898  3.202064  1.800255
# 3   0.690207 -2.802670  0.039824 -0.452984  0.733203  1.993621  1.060869
# 4   1.113541 -4.343674  1.501242  2.608504  0.282633  0.814241  0.213915
# 5   5.128034  1.427013  2.126658 -1.648347 -1.303841  1.406333 -0.127719
# 6  -2.445671  1.134385 -1.713168 -0.535495 -0.986413  0.559286 -1.348857
# 7  -1.285835  1.133684 -1.393384 -1.788763  0.078967 -1.628220  4.693191
# 8  -0.854012 -1.193327 -0.588850  2.234394  2.346093  1.707645 -0.681292
# 9  -0.702521  1.271145 -0.267257  0.872589 -0.380151  1.107034 -0.327619
# 10 -2.587016  1.464129 -1.821883 -1.056494 -0.748153  0.084673 -0.027633
# 11 -1.759722  1.916686 -1.196228 -1.951797 -0.296337 -0.379737  5.052129
# 12 -0.346966  1.337435 -0.663736  4.572681  0.073777  4.301911  1.663476
# 13 -0.412273  1.844655 -2.696428 -0.063892  5.556841 -1.498817 -2.011895
# 14 -0.073305  3.920519 -1.959430 -0.069064  2.512656 -2.237360  4.651502
# 15  0.881987 -4.473841  0.864717  1.315994  0.175263 -0.339045  0.574539
# 16  2.238088 -2.893358  1.833819  1.225518  1.368679  2.349269  1.119980
# 17 -1.725840  2.808052  0.925126 -0.737311 -0.873001  1.432953 -1.464233
# 18 -0.897123  3.443295 -3.172407 -0.615858  3.124297 -0.835252 -1.841146
# 19 -0.600887  1.694825 -0.374315  4.841975 -0.223827  4.879057  2.413605
# 20  4.481309  3.742067  7.384269 -0.076563  1.788728 -2.049059  0.834935
# 21 -0.336426  3.940754 -1.945446 -0.094166  2.092961 -1.724065  3.823169
# 22  0.087226  3.198365 -1.771537  0.330240  1.987260 -2.481010  4.008752
# 23 -0.608029  0.217390 -0.441299  2.594773 -0.862286  1.063373 -0.335407
# 24 -2.160789  0.760775 -1.452847 -0.322658 -1.350275  0.653674 -0.313618
#
#          PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0   0.146634 -0.643450  1.333976  ...           0            2            0
# 1   1.873284  0.665698 -0.663097  ...           6            2            0
# 2   3.991179  1.138871 -0.348235  ...           0            7            0
# 3  -0.541040 -1.755796  0.481612  ...           0            0            0
# 4  -1.158998 -1.689059 -1.494052  ...           0            2            0
# 5  -0.215946 -0.064337 -1.196106  ...          18           11            0
# 6   0.643940 -0.729132  1.023333  ...           0           18            1
# 7  -3.519059  2.202286 -0.619369  ...           2           19            1
# 8  -0.612474  0.350221  0.975957  ...           5            1            0
# 9  -0.768621 -0.017278  0.856384  ...           0            3            0
# 10  1.348658 -1.112430  0.361637  ...           0            5            0
# 11 -3.254225  1.610442 -0.819009  ...           0           14            0
# 12  2.858176  0.833473 -0.149637  ...           0            4            0
# 13  1.300058  0.653157 -1.295375  ...           1           10            0
# 14  0.735364 -1.639519 -1.288615  ...           0            5            0
# 15  0.050907 -1.597287 -1.350042  ...           0            4            0
# 16 -1.447385 -2.678456  1.568138  ...           0            2            0
# 17  0.811507  0.351764 -0.366633  ...          19           32            0
# 18  1.006994 -0.983460 -0.728592  ...           0            5            0
# 19  3.677418  1.281705 -1.472060  ...           1            0            0
# 20 -0.153368 -1.481640  1.997094  ...           2            6            0
# 21  0.880170 -1.130517 -0.720366  ...           0            2            0
# 22 -0.647871  0.072922 -0.806582  ...           0           13            0
# 23 -2.279005  0.059385  1.871976  ...           0            2            0
# 24  1.206313  0.012093  0.955768  ...           0            4            1
#
#     FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0             1                1             4              8
# 1             0                0             0              8
# 2             0                0             0              7
# 3             1                0             3              4
# 4             0                0             0              2
# 5             0                0             0             28
# 6             5                0             1             25
# 7             2                0             0             24
# 8             3                0             0              9
# 9             0                0             5              8
# 10            0                0             0              5
# 11            0                0             0             14
# 12            0                0             0              4
# 13            1                0             0             12
# 14            1                0             0              6
# 15            0                0             0              4
# 16            0                0             0              2
# 17            0                0             0             51
# 18            1                0             0              6
# 19            0                0             0              1
# 20            0                0             0              8
# 21            5                0             0              6
# 22            0                0             0             13
# 23            0                0             0              2
# 24            9                0             0             14
#
#     CalculatedSecondQuality  Defect  OrderQuantity
# 0                         8      12            370
# 1                         8       8            160
# 2                         7      12            205
# 3                         4       6            185
# 4                         2      11            185
# 5                        29      54           1600
# 6                        25      32            300
# 7                        24      32            420
# 8                         9      17            200
# 9                         8      10            205
# 10                        5       7            220
# 11                       14      17            420
# 12                        4       6            200
# 13                       12      17            250
# 14                        6      11            300
# 15                        4       8            205
# 16                        2       8            250
# 17                       51      80           1995
# 18                        6      11            250
# 19                        1       1            160
# 20                        8      20           1545
# 21                        7       7            300
# 22                       13      19            250
# 23                        2       3            200
# 24                       14      16            220
#
# [25 rows x 41 columns]

# %%
#Information of validationFrame is being printed
validationFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      25 non-null     float64
#  1   PC1                      25 non-null     float64
#  2   PC2                      25 non-null     float64
#  3   PC3                      25 non-null     float64
#  4   PC4                      25 non-null     float64
#  5   PC5                      25 non-null     float64
#  6   PC6                      25 non-null     float64
#  7   PC7                      25 non-null     float64
#  8   PC8                      25 non-null     float64
#  9   PC9                      25 non-null     float64
#  10  PC10                     25 non-null     float64
#  11  PC11                     25 non-null     float64
#  12  PC12                     25 non-null     float64
#  13  PC13                     25 non-null     float64
#  14  PC14                     25 non-null     float64
#  15  PC15                     25 non-null     float64
#  16  PC16                     25 non-null     float64
#  17  PC17                     25 non-null     float64
#  18  PC18                     25 non-null     float64
#  19  PC19                     25 non-null     float64
#  20  PC20                     25 non-null     float64
#  21  PC21                     25 non-null     float64
#  22  PC22                     25 non-null     float64
#  23  PrintErrorRate           25 non-null     float64
#  24  SewingErrorRate          25 non-null     float64
#  25  FabricStainRate          25 non-null     float64
#  26  FabricErrorRate          25 non-null     float64
#  27  EmbroideryErrorRate      25 non-null     float64
#  28  MeasureErrorRate         25 non-null     float64
#  29  SecondQualityRate        25 non-null     float64
#  30  DefectRate               25 non-null     float64
#  31  PrintError               25 non-null     int64
#  32  SewingError              25 non-null     int64
#  33  FabricStain              25 non-null     int64
#  34  FabricError              25 non-null     int64
#  35  EmbroideryError          25 non-null     int64
#  36  MeasureError             25 non-null     int64
#  37  SecondQuality            25 non-null     int64
#  38  CalculatedSecondQuality  25 non-null     int64
#  39  Defect                   25 non-null     int64
#  40  OrderQuantity            25 non-null     int64
# dtypes: float64(31), int64(10)
# memory usage: 8.1 KB

# %%
#Statistical information of validationFrame part to use is being printed
validationFrame.loc[:, : 'DefectRate'].describe()
# Out:
#              PC0        PC1        PC2        PC3        PC4        PC5  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean   -0.178009   0.841029  -0.330317   0.694910   0.526580   0.612656
# std     1.875163   2.388770   2.098771   2.001808   1.694058   2.025949
# min    -2.587016  -4.473841  -3.172407  -1.951797  -1.512157  -2.481010
# 25%    -1.285835   0.217390  -1.713168  -0.615858  -0.748153  -0.835252
# 50%    -0.600887   1.337435  -0.663736  -0.069064   0.073777   0.653674
# 75%     0.087226   1.916686   0.039824   2.234394   1.788728   1.707645
# max     5.128034   3.940754   7.384269   4.841975   5.556841   4.879057
#
#              PC6        PC7        PC8        PC9  ...       PC21       PC22  \
# count  25.000000  25.000000  25.000000  25.000000  ...  25.000000  25.000000
# mean    1.003164   0.237304  -0.251614  -0.075676  ...  -0.056123   0.055990
# std     2.104197   1.842426   1.217884   1.119167  ...   1.288558   0.676082
# min    -2.011895  -3.519059  -2.678456  -1.494052  ...  -2.051919  -1.644212
# 25%    -0.335407  -0.647871  -1.130517  -0.819009  ...  -0.831484  -0.383883
# 50%     0.574539   0.146634  -0.017278  -0.366633  ...  -0.181466  -0.112759
# 75%     1.986794   1.206313   0.653157   0.955768  ...   0.591302   0.639270
# max     5.052129   3.991179   2.202286   1.997094  ...   3.210872   1.135576
#
#        PrintErrorRate  SewingErrorRate  FabricStainRate  FabricErrorRate  \
# count       25.000000        25.000000        25.000000        25.000000
# mean         0.003628         0.017052         0.000371         0.004010
# std          0.008077         0.014952         0.001057         0.008141
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.005405         0.000000         0.000000
# 50%          0.000000         0.014563         0.000000         0.000000
# 75%          0.003546         0.020161         0.000000         0.003571
# max          0.033520         0.053892         0.004032         0.036290
#
#        EmbroideryErrorRate  MeasureErrorRate  SecondQualityRate  DefectRate
# count            25.000000         25.000000          25.000000   25.000000
# mean              0.000098          0.001959           0.027119    0.042068
# std               0.000491          0.005363           0.018203    0.022033
# min               0.000000          0.000000           0.004678    0.005587
# 25%               0.000000          0.000000           0.017007    0.028846
# 50%               0.000000          0.000000           0.020161    0.038672
# 75%               0.000000          0.000000           0.040541    0.054054
# max               0.002457          0.021739           0.074850    0.095808
#
# [8 rows x 31 columns]

# %%
#validationX is being created with input features of validationFrame
validationX = validationFrame.loc[:, : 'PC22'].values
validationX.shape
# Out:
# (25, 23)

# %%
#validationY is being created with Error Rate features of validationFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
validationY = validationFrame.loc[:, 'PrintErrorRate' : 'DefectRate'].values * 100
validationY.shape
# Out:
# (25, 8)

# %%
#predictions are being made by trained regressor on validationX data
predictions = regressor.predict(validationX)
predictions.shape
# Out:
# (25, 8)

# %%
#resultFrame based on predictions and real values is being created
resultDict = {'Model' : [], 'Data' : [], 'ColumName' : [], 'MeanAbsoluteError' : [],
              'MeanSquaredError' : [], 'SqrtMeanSquaredError' : []}
for i in range(predictions.shape[1]):
    resultDict['Model'].append(MODEL_NAME)
    resultDict['Data'].append('Validation')
    resultDict['ColumName'].append(outputName[i])
    resultDict['MeanAbsoluteError'].append(mean_absolute_error(validationY[:,i], predictions[:,i]))
    resultDict['MeanSquaredError'].append(mean_squared_error(validationY[:,i], predictions[:,i]))
    resultDict['SqrtMeanSquaredError'].append(np.sqrt(mean_squared_error(validationY[:,i], predictions[:,i])))
    
resultDict['Model'].append(MODEL_NAME)
resultDict['Data'].append('Validation')
resultDict['ColumName'].append('Average')
resultDict['MeanAbsoluteError'].append(np.mean(resultDict['MeanAbsoluteError']))
resultDict['MeanSquaredError'].append(np.mean(resultDict['MeanSquaredError']))
resultDict['SqrtMeanSquaredError'].append(np.mean(resultDict['SqrtMeanSquaredError']))

resultFrame = pd.concat([resultFrame, pd.DataFrame(resultDict)]).reset_index(drop = True)
resultFrame
# Out:
#    Model        Data            ColumName  MeanAbsoluteError  \
# 0    SVR    Training       PrintErrorRate           0.305200
# 1    SVR    Training      SewingErrorRate           0.638757
# 2    SVR    Training      FabricStainRate           0.110003
# 3    SVR    Training      FabricErrorRate           0.301352
# 4    SVR    Training  EmbroideryErrorRate           0.110171
# 5    SVR    Training     MeasureErrorRate           0.134291
# 6    SVR    Training    SecondQualityRate           0.837695
# 7    SVR    Training           DefectRate           1.333833
# 8    SVR    Training              Average           0.471413
# 9    SVR  Validation       PrintErrorRate           0.405879
# 10   SVR  Validation      SewingErrorRate           1.086938
# 11   SVR  Validation      FabricStainRate           0.127658
# 12   SVR  Validation      FabricErrorRate           0.541574
# 13   SVR  Validation  EmbroideryErrorRate           0.114342
# 14   SVR  Validation     MeasureErrorRate           0.278768
# 15   SVR  Validation    SecondQualityRate           1.455426
# 16   SVR  Validation           DefectRate           2.043972
# 17   SVR  Validation              Average           0.756820
#
#     MeanSquaredError  SqrtMeanSquaredError
# 0           0.500667              0.707578
# 1           1.005050              1.002522
# 2           0.029252              0.171031
# 3           0.363148              0.602618
# 4           0.044925              0.211955
# 5           0.140288              0.374551
# 6           1.835184              1.354690
# 7           3.429191              1.851807
# 8           0.918463              0.784594
# 9           0.628054              0.792499
# 10          2.491709              1.578515
# 11          0.021158              0.145459
# 12          0.774143              0.879854
# 13          0.020251              0.142308
# 14          0.295453              0.543556
# 15          3.803696              1.950307
# 16          6.902056              2.627176
# 17          1.867065              1.082459

# %%
#testFrame is being created by reading a pkl file
testFrame = pd.read_pickle("../../../Data/DataSplit/Test.pkl")
testFrame
# Out:
#           PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0   -2.013910  1.995143 -1.926260 -1.974847 -0.470229 -0.920815  5.463404
# 1    0.081436  0.312799 -0.204645  4.329446 -0.406149  3.267323  2.083090
# 2   -0.275271  3.378519  6.180660 -3.070387 -1.256094  2.695950 -1.440188
# 3    0.943398 -4.813578  0.824529  0.275050  0.786546  0.370814  0.870501
# 4   -0.379232  3.409618 -3.162239  2.686746  3.859326  0.532266 -1.527445
# 5   -2.101637  2.223838 -1.556957 -2.129927 -0.512525 -0.824300  5.273366
# 6   -0.282043  3.811182 -2.230863  0.004519  2.087936 -1.753659  3.935391
# 7   -0.643040  0.346454 -0.315427  2.190501 -1.220767  2.136473  0.156331
# 8   12.352104 -1.044931 -5.463644 -0.329819 -2.043098 -0.491714 -0.910660
# 9   -2.104799  0.395125 -1.107901 -1.055992 -1.160363 -0.341301 -0.616943
# 10  -0.499595  1.831311 -2.527657  0.456371  5.226237 -0.821758 -3.551327
# 11   0.277281 -1.755565  0.415892  4.360810 -0.620728 -0.945571  1.144859
# 12  -2.551436  1.036332 -1.216884 -1.558052 -1.634288  0.276052  0.200355
# 13  -2.545017  1.544369 -1.551598 -1.156209 -0.736147  0.087782 -0.070930
# 14   0.085605  3.217635 -1.731752  0.313193  1.983401 -2.474916  3.995955
# 15  -0.407944  1.036587 -0.538082  2.514105 -0.207685  2.572053  0.625483
# 16  -0.221149 -2.486702  0.195641 -2.642878  0.648723  1.511509  0.692675
# 17   3.442993  3.858221  7.682068 -4.955933 -2.546559  3.279513 -2.898216
# 18  -0.467885 -1.390994  0.269207  4.371193 -1.487649 -1.176239 -0.887723
# 19  -1.699623  0.284938 -0.174223 -2.014745 -1.478593  0.233021 -1.102864
# 20   0.487685 -4.105341  1.566166 -1.425481  0.143102 -0.849267  0.674443
# 21  -0.081952 -1.834765  1.527939  0.421251 -1.956065 -3.651559 -0.367304
# 22  -0.562743 -1.143406  0.662036  3.877318 -1.839055 -0.080621 -0.500330
# 23   0.251189  0.091663 -0.085204  2.469710  0.351512  1.026921  0.356378
# 24  -0.758804  1.165996 -0.595736  1.022706 -0.305360  1.472206  0.762262
#
#          PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0  -2.759364  2.244603 -0.119326  ...           2           15            5
# 1   1.907919  0.579843 -0.524113  ...           0            3            0
# 2  -1.783384  1.923091 -3.025943  ...          93           26            2
# 3   0.563257 -2.901741 -3.165466  ...           0            3            1
# 4  -1.047937 -1.601517 -0.551928  ...           0            0            0
# 5  -2.782388  2.460166 -0.430639  ...           0           11            0
# 6   0.919443 -1.236278 -0.553032  ...           0           10            0
# 7  -2.538222 -0.720663  1.731993  ...           1            4            0
# 8   0.539819  3.024043  0.518843  ...           3            1            0
# 9  -0.333464  0.484331  0.650698  ...           0            1            0
# 10  0.671307  1.260943 -0.887118  ...           1            5            0
# 11  2.711760  0.356664 -0.964075  ...           0            1            0
# 12  0.162104  0.393098  1.047345  ...           0            9            0
# 13  1.297714 -1.069741  0.286517  ...           5            2            0
# 14 -0.651181  0.089724 -0.831912  ...           0           18            0
# 15 -2.290589 -0.591441  1.032603  ...           0            5            0
# 16  0.161640 -1.606857 -0.577019  ...           0            4            0
# 17 -1.436746  2.861091 -5.528565  ...          80           29            8
# 18 -1.631892  0.318784 -0.067015  ...           0            0            0
# 19 -0.501114 -0.265515  0.426784  ...           0            8            0
# 20  1.333707 -2.836730 -3.549777  ...           0            2            0
# 21  0.133724 -0.906136 -0.584015  ...           0            3            0
# 22 -1.927437 -0.364085 -0.364298  ...           0            2            0
# 23 -2.739869 -0.104364  1.257829  ...           3            1            0
# 24 -1.157585 -0.286044  0.834005  ...           0            9            0
#
#     FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0             2                0             2             25
# 1             1                0             0              4
# 2             3                0             0            123
# 3             0                0             0              4
# 4             0                5             0              5
# 5             3                0             0             14
# 6             2                0             0             11
# 7             2                0             0              7
# 8             0                0             0              4
# 9             0                0             0              1
# 10            1                0             0              7
# 11            0                0             0              1
# 12            2                0             0             11
# 13            2                0             0              9
# 14            2                0             0             20
# 15            1                0             0              6
# 16            1                0             0              5
# 17            7                4             0            127
# 18            2                0             0              2
# 19            2                0             0             10
# 20            0                0             0              2
# 21            0                0             0              3
# 22            0                0             0              2
# 23            0                0             0              4
# 24            3                0             0             12
#
#     CalculatedSecondQuality  Defect  OrderQuantity
# 0                        26      32            420
# 1                         4       5            150
# 2                       124     143           4395
# 3                         4       5            200
# 4                         5       7            170
# 5                        14      18            450
# 6                        12      18            250
# 7                         7       9            210
# 8                         4      10            190
# 9                         1       4            220
# 10                        7       8            250
# 11                        1       8            150
# 12                       11      21            500
# 13                        9      17            500
# 14                       20      28            250
# 15                        6      13            200
# 16                        5       8            400
# 17                      128     199           6000
# 18                        2       5            220
# 19                       10      15            500
# 20                        2      13            400
# 21                        3      11            400
# 22                        2      11            210
# 23                        4      11            200
# 24                       12      19            205
#
# [25 rows x 41 columns]

# %%
#Information of testFrame is being printed
testFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      25 non-null     float64
#  1   PC1                      25 non-null     float64
#  2   PC2                      25 non-null     float64
#  3   PC3                      25 non-null     float64
#  4   PC4                      25 non-null     float64
#  5   PC5                      25 non-null     float64
#  6   PC6                      25 non-null     float64
#  7   PC7                      25 non-null     float64
#  8   PC8                      25 non-null     float64
#  9   PC9                      25 non-null     float64
#  10  PC10                     25 non-null     float64
#  11  PC11                     25 non-null     float64
#  12  PC12                     25 non-null     float64
#  13  PC13                     25 non-null     float64
#  14  PC14                     25 non-null     float64
#  15  PC15                     25 non-null     float64
#  16  PC16                     25 non-null     float64
#  17  PC17                     25 non-null     float64
#  18  PC18                     25 non-null     float64
#  19  PC19                     25 non-null     float64
#  20  PC20                     25 non-null     float64
#  21  PC21                     25 non-null     float64
#  22  PC22                     25 non-null     float64
#  23  PrintErrorRate           25 non-null     float64
#  24  SewingErrorRate          25 non-null     float64
#  25  FabricStainRate          25 non-null     float64
#  26  FabricErrorRate          25 non-null     float64
#  27  EmbroideryErrorRate      25 non-null     float64
#  28  MeasureErrorRate         25 non-null     float64
#  29  SecondQualityRate        25 non-null     float64
#  30  DefectRate               25 non-null     float64
#  31  PrintError               25 non-null     int64
#  32  SewingError              25 non-null     int64
#  33  FabricStain              25 non-null     int64
#  34  FabricError              25 non-null     int64
#  35  EmbroideryError          25 non-null     int64
#  36  MeasureError             25 non-null     int64
#  37  SecondQuality            25 non-null     int64
#  38  CalculatedSecondQuality  25 non-null     int64
#  39  Defect                   25 non-null     int64
#  40  OrderQuantity            25 non-null     int64
# dtypes: float64(31), int64(10)
# memory usage: 8.1 KB

# %%
#Statistical information of testFrame part to use is being printed
testFrame.loc[:, : 'DefectRate'].describe()
# Out:
#              PC0        PC1        PC2        PC3        PC4        PC5  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.013024   0.454578  -0.202597   0.279146  -0.191783   0.205207
# std     2.863422   2.356419   2.651003   2.553474   1.846505   1.743946
# min    -2.551436  -4.813578  -5.463644  -4.955933  -2.546559  -3.651559
# 25%    -0.758804  -1.143406  -1.556957  -1.558052  -1.478593  -0.849267
# 50%    -0.379232   0.395125  -0.315427   0.275050  -0.512525   0.087782
# 75%     0.085605   1.995143   0.415892   2.469710   0.351512   1.472206
# max    12.352104   3.858221   7.682068   4.371193   5.226237   3.279513
#
#              PC6        PC7        PC8        PC9  ...       PC21       PC22  \
# count  25.000000  25.000000  25.000000  25.000000  ...  25.000000  25.000000
# mean    0.494423  -0.527151   0.060211  -0.557505  ...   0.567818   0.239675
# std     2.241005   1.566362   1.592350   1.674245  ...   1.379990   0.852453
# min    -3.551327  -2.782388  -2.901741  -5.528565  ...  -1.965344  -2.033394
# 25%    -0.887723  -1.783384  -0.906136  -0.831912  ...  -0.529781  -0.181202
# 50%     0.200355  -0.501114  -0.104364  -0.430639  ...   0.848378   0.480764
# 75%     0.870501   0.563257   0.579843   0.518843  ...   1.588861   0.707311
# max     5.463404   2.711760   3.024043   1.731993  ...   3.393513   2.035233
#
#        PrintErrorRate  SewingErrorRate  FabricStainRate  FabricErrorRate  \
# count       25.000000        25.000000        25.000000        25.000000
# mean         0.003294         0.015150         0.000676         0.003143
# std          0.005886         0.015264         0.002298         0.003419
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.004693         0.000000         0.000000
# 50%          0.000000         0.009050         0.000000         0.003546
# 75%          0.004255         0.018182         0.000000         0.004545
# max          0.020480         0.065657         0.010799         0.013158
#
#        EmbroideryErrorRate  MeasureErrorRate  SecondQualityRate  DefectRate
# count            25.000000         25.000000          25.000000   25.000000
# mean              0.001066          0.000173           0.023501    0.041856
# std               0.005205          0.000864           0.016756    0.020805
# min               0.000000          0.000000           0.004032    0.016129
# 25%               0.000000          0.000000           0.011312    0.029144
# 50%               0.000000          0.000000           0.020590    0.036458
# 75%               0.000000          0.000000           0.027273    0.048193
# max               0.026042          0.004320           0.070707    0.101010
#
# [8 rows x 31 columns]

# %%
#testX is being created with input features of testFrame
testX = testFrame.loc[:, : 'PC22'].values
testX.shape
# Out:
# (25, 23)

# %%
#testY is being created with Error Rate features of testFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
testY = testFrame.loc[:, 'PrintErrorRate' : 'DefectRate'].values * 100
testY.shape
# Out:
# (25, 8)

# %%
#predictions are being made by trained regressor on testX data
predictions = regressor.predict(testX)
predictions.shape
# Out:
# (25, 8)

# %%
#resultFrame based on predictions and real values is being created
resultDict = {'Model' : [], 'Data' : [], 'ColumName' : [], 'MeanAbsoluteError' : [],
              'MeanSquaredError' : [], 'SqrtMeanSquaredError' : []}
for i in range(predictions.shape[1]):
    resultDict['Model'].append(MODEL_NAME)
    resultDict['Data'].append('Test')
    resultDict['ColumName'].append(outputName[i])
    resultDict['MeanAbsoluteError'].append(mean_absolute_error(testY[:,i], predictions[:,i]))
    resultDict['MeanSquaredError'].append(mean_squared_error(testY[:,i], predictions[:,i]))
    resultDict['SqrtMeanSquaredError'].append(np.sqrt(mean_squared_error(testY[:,i], predictions[:,i])))
    
resultDict['Model'].append(MODEL_NAME)
resultDict['Data'].append('Test')
resultDict['ColumName'].append('Average')
resultDict['MeanAbsoluteError'].append(np.mean(resultDict['MeanAbsoluteError']))
resultDict['MeanSquaredError'].append(np.mean(resultDict['MeanSquaredError']))
resultDict['SqrtMeanSquaredError'].append(np.mean(resultDict['SqrtMeanSquaredError']))

resultFrame = pd.concat([resultFrame, pd.DataFrame(resultDict)]).reset_index(drop = True)
resultFrame
# Out:
#    Model        Data            ColumName  MeanAbsoluteError  \
# 0    SVR    Training       PrintErrorRate           0.305200
# 1    SVR    Training      SewingErrorRate           0.638757
# 2    SVR    Training      FabricStainRate           0.110003
# 3    SVR    Training      FabricErrorRate           0.301352
# 4    SVR    Training  EmbroideryErrorRate           0.110171
# 5    SVR    Training     MeasureErrorRate           0.134291
# 6    SVR    Training    SecondQualityRate           0.837695
# 7    SVR    Training           DefectRate           1.333833
# 8    SVR    Training              Average           0.471413
# 9    SVR  Validation       PrintErrorRate           0.405879
# 10   SVR  Validation      SewingErrorRate           1.086938
# 11   SVR  Validation      FabricStainRate           0.127658
# 12   SVR  Validation      FabricErrorRate           0.541574
# 13   SVR  Validation  EmbroideryErrorRate           0.114342
# 14   SVR  Validation     MeasureErrorRate           0.278768
# 15   SVR  Validation    SecondQualityRate           1.455426
# 16   SVR  Validation           DefectRate           2.043972
# 17   SVR  Validation              Average           0.756820
# 18   SVR        Test       PrintErrorRate           0.405344
# 19   SVR        Test      SewingErrorRate           0.984241
# 20   SVR        Test      FabricStainRate           0.139409
# 21   SVR        Test      FabricErrorRate           0.308660
# 22   SVR        Test  EmbroideryErrorRate           0.180094
# 23   SVR        Test     MeasureErrorRate           0.117259
# 24   SVR        Test    SecondQualityRate           1.068982
# 25   SVR        Test           DefectRate           1.406523
# 26   SVR        Test              Average           0.576314
#
#     MeanSquaredError  SqrtMeanSquaredError
# 0           0.500667              0.707578
# 1           1.005050              1.002522
# 2           0.029252              0.171031
# 3           0.363148              0.602618
# 4           0.044925              0.211955
# 5           0.140288              0.374551
# 6           1.835184              1.354690
# 7           3.429191              1.851807
# 8           0.918463              0.784594
# 9           0.628054              0.792499
# 10          2.491709              1.578515
# 11          0.021158              0.145459
# 12          0.774143              0.879854
# 13          0.020251              0.142308
# 14          0.295453              0.543556
# 15          3.803696              1.950307
# 16          6.902056              2.627176
# 17          1.867065              1.082459
# 18          0.392111              0.626188
# 19          2.295603              1.515125
# 20          0.052154              0.228373
# 21          0.141765              0.376517
# 22          0.254616              0.504594
# 23          0.020482              0.143117
# 24          2.078826              1.441814
# 25          3.436734              1.853843
# 26          1.084036              0.836196

# %%
#Chart to show the closeness of the PrintErrorRate predictions to the true values is being plaotted
index = 0
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the SewingErrorRate predictions to the true values is being plaotted
index = 1
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the FabricStainRate predictions to the true values is being plaotted
index = 2
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the FabricErrorRate predictions to the true values is being plaotted
index = 3
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the EmbroideryErrorRate predictions to the true values is being plaotted
index = 4
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the MeasureErrorRate predictions to the true values is being plaotted
index = 5
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the SecondQualityRate predictions to the true values is being plaotted
index = 6
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Chart to show the closeness of the DefectRate predictions to the true values is being plaotted
index = 7
DrawChart(outputName[index], testY[:, index], predictions[:, index])

# %%
#Trained regressor is being saved for feature use
dump(regressor, '../../Model/MultiOutput/SVR/SVR.joblib')
# Out:
# ['../../Model/MultiOutput/SVR/SVR.joblib']

# %%
#Information of resultFram is being printed
resultFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 27 non-null     object
#  1   Data                  27 non-null     object
#  2   ColumName             27 non-null     object
#  3   MeanAbsoluteError     27 non-null     float64
#  4   MeanSquaredError      27 non-null     float64
#  5   SqrtMeanSquaredError  27 non-null     float64
# dtypes: float64(3), object(3)
# memory usage: 1.4+ KB

# %%
#Statistical information of resultFram is being printed
resultFrame.describe()
# Out:
#        MeanAbsoluteError  MeanSquaredError  SqrtMeanSquaredError
# count          27.000000         27.000000             27.000000
# mean            0.601515          1.289855              0.901083
# std             0.516298          1.619209              0.665651
# min             0.110003          0.020251              0.142308
# 25%             0.159751          0.141027              0.375534
# 50%             0.405879          0.628054              0.784594
# 75%             0.910968          1.972946              1.398252
# max             2.043972          6.902056              2.627176

# %%
#resultFrame is being saved as pkl files
resultFrame.to_pickle('../../Model/MultiOutput/SVR/ResultFrame.pkl')
