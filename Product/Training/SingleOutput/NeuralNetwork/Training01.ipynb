# %% [markdown]
# # Artificial Neural Network
#
# In this notebook file, an ANN model will be trained with FabricWaste data for predict SecondQualityRate

# %%
#Libraries are being imported
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlibVersion

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import __version__ as sklearnVersion

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MSE
from tensorflow.keras.metrics import MAE
from tensorflow.keras.callbacks import Callback
from tensorflow import __version__ as tensorflowVersion

# %%
#Library versions are being printed
print('numpy Version: ' + np.__version__)
print('pandas Version: ' + pd.__version__)
print('matplotlib Version: ' + matplotlibVersion)
print('sklearn Version: ' + sklearnVersion)
print('tensorflow Version: ' + tensorflowVersion)
# Out:
# numpy Version: 1.23.5
# pandas Version: 1.5.2
# matplotlib Version: 3.6.2
# sklearn Version: 1.2.0
# tensorflow Version: 2.10.0

# %%
#Constants are being defined
MODEL_NAME = 'ANN'
EPOCH_NUMBER = 50
BATCH_SIZE = 64

# %%
#trainingFrame is being created by reading a pkl file
trainingFrame = pd.read_pickle("../../../Data/DataSplit/Training.pkl")
trainingFrame.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -2.159842  0.903073 -0.903965 -0.494504 -1.292695  0.619725 -0.410849
# 1  0.162054 -1.141753 -0.219059  1.554529  1.432512 -0.847058 -0.229250
# 2 -0.249417 -2.523880  0.002460 -2.579382  0.628535  1.531744  0.705912
# 3 -0.993506 -0.761118  0.053950 -1.878065 -1.164023 -1.238222 -0.260116
# 4  4.394100  4.620156  6.910180  0.250664  2.236256 -1.335311  1.639115
#
#         PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0  1.097258  0.081156  0.803563  ...           6            1            0
# 1  0.049316  3.855226  1.932691  ...           0           19            1
# 2  0.202348 -1.614852 -0.546322  ...           0            5            0
# 3 -0.716803 -1.282542  1.161412  ...           0            1            0
# 4  1.140519 -2.365281  4.222803  ...          17           12            1
#
#    FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0            0                0             0              7
# 1            5                0             1             26
# 2            0                0             0              5
# 3            0                0             0              1
# 4            0                0             0             30
#
#    CalculatedSecondQuality  Defect  OrderQuantity
# 0                        7      15            380
# 1                       26      33            295
# 2                        5      21            310
# 3                        1       6            370
# 4                       30      44           1645
#
# [5 rows x 41 columns]

# %%
#Information of trainingFrame is being printed
trainingFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      150 non-null    float64
#  1   PC1                      150 non-null    float64
#  2   PC2                      150 non-null    float64
#  3   PC3                      150 non-null    float64
#  4   PC4                      150 non-null    float64
#  5   PC5                      150 non-null    float64
#  6   PC6                      150 non-null    float64
#  7   PC7                      150 non-null    float64
#  8   PC8                      150 non-null    float64
#  9   PC9                      150 non-null    float64
#  10  PC10                     150 non-null    float64
#  11  PC11                     150 non-null    float64
#  12  PC12                     150 non-null    float64
#  13  PC13                     150 non-null    float64
#  14  PC14                     150 non-null    float64
#  15  PC15                     150 non-null    float64
#  16  PC16                     150 non-null    float64
#  17  PC17                     150 non-null    float64
#  18  PC18                     150 non-null    float64
#  19  PC19                     150 non-null    float64
#  20  PC20                     150 non-null    float64
#  21  PC21                     150 non-null    float64
#  22  PC22                     150 non-null    float64
#  23  PrintErrorRate           150 non-null    float64
#  24  SewingErrorRate          150 non-null    float64
#  25  FabricStainRate          150 non-null    float64
#  26  FabricErrorRate          150 non-null    float64
#  27  EmbroideryErrorRate      150 non-null    float64
#  28  MeasureErrorRate         150 non-null    float64
#  29  SecondQualityRate        150 non-null    float64
#  30  DefectRate               150 non-null    float64
#  31  PrintError               150 non-null    int64
#  32  SewingError              150 non-null    int64
#  33  FabricStain              150 non-null    int64
#  34  FabricError              150 non-null    int64
#  35  EmbroideryError          150 non-null    int64
#  36  MeasureError             150 non-null    int64
#  37  SecondQuality            150 non-null    int64
#  38  CalculatedSecondQuality  150 non-null    int64
#  39  Defect                   150 non-null    int64
#  40  OrderQuantity            150 non-null    int64
# dtypes: float64(31), int64(10)
# memory usage: 48.2 KB

# %%
#Statistical information of trainingFrame part to use is being printed
trainingFrame.loc[:, : 'DefectRate'].describe()
# Out:
#                 PC0           PC1           PC2           PC3           PC4  \
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean   2.368476e-17 -1.125026e-16 -1.065814e-16 -2.368476e-17 -2.368476e-17
# std    2.742575e+00  2.575942e+00  2.354006e+00  2.106912e+00  1.869427e+00
# min   -2.593435e+00 -5.356644e+00 -5.332553e+00 -3.363834e+00 -3.622670e+00
# 25%   -1.663962e+00 -1.592389e+00 -1.189392e+00 -1.525014e+00 -1.378872e+00
# 50%   -4.565722e-01  3.784231e-01 -2.626697e-01 -5.582300e-01 -6.168971e-01
# 75%    3.168803e-01  1.385057e+00  7.821502e-01  1.150648e+00  1.266148e+00
# max    1.304181e+01  5.395295e+00  1.014250e+01  6.680256e+00  5.805823e+00
#
#                 PC5           PC6           PC7           PC8           PC9  \
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean   1.539509e-16  4.736952e-17 -1.894781e-16  4.144833e-17 -1.465494e-16
# std    1.709458e+00  1.562710e+00  1.494945e+00  1.336939e+00  1.319240e+00
# min   -4.180609e+00 -3.077161e+00 -3.586945e+00 -3.568800e+00 -4.299588e+00
# 25%   -1.195458e+00 -6.770874e-01 -8.965826e-01 -8.102841e-01 -8.504962e-01
# 50%    1.307688e-01 -2.511817e-01  3.859758e-02 -1.363654e-01  1.792644e-03
# 75%    1.173204e+00  4.458845e-01  9.306250e-01  5.667936e-01  6.908789e-01
# max    4.858948e+00  5.377690e+00  5.203551e+00  3.855226e+00  5.227225e+00
#
#        ...          PC21          PC22  PrintErrorRate  SewingErrorRate  \
# count  ...  1.500000e+02  1.500000e+02      150.000000       150.000000
# mean   ... -5.921189e-17 -1.125026e-16        0.004084         0.013615
# std    ...  9.204159e-01  9.104180e-01        0.008244         0.012301
# min    ... -2.169231e+00 -3.550595e+00        0.000000         0.000000
# 25%    ... -5.420482e-01 -3.440578e-01        0.000000         0.004617
# 50%    ... -4.370206e-02  1.117789e-01        0.000000         0.009662
# 75%    ...  4.777897e-01  5.891056e-01        0.004640         0.017848
# max    ...  2.954614e+00  4.063812e+00        0.044643         0.058282
#
#        FabricStainRate  FabricErrorRate  EmbroideryErrorRate  \
# count       150.000000       150.000000           150.000000
# mean          0.000712         0.004679             0.000547
# std           0.001953         0.007235             0.002289
# min           0.000000         0.000000             0.000000
# 25%           0.000000         0.000000             0.000000
# 50%           0.000000         0.002206             0.000000
# 75%           0.000000         0.006057             0.000000
# max           0.013158         0.041667             0.015060
#
#        MeasureErrorRate  SecondQualityRate  DefectRate
# count        150.000000         150.000000  150.000000
# mean           0.000825           0.024462    0.045132
# std            0.004019           0.017073    0.023845
# min            0.000000           0.002262    0.009091
# 25%            0.000000           0.012884    0.028450
# 50%            0.000000           0.020761    0.039438
# 75%            0.000000           0.030945    0.059436
# max            0.044643           0.079755    0.118812
#
# [8 rows x 31 columns]

# %%
#trainingX is being created with input features of trainingFrame
trainingX = trainingFrame.loc[:, : 'PC22'].values
trainingX.shape
# Out:
# (150, 23)

# %%
#trainingY is being created with SecondQualityRate feature of trainingFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
trainingY = trainingFrame['SecondQualityRate'].values.reshape(-1, 1) * 100
trainingY.shape
# Out:
# (150, 1)

# %%
#validationFrame is being created by reading a pkl file
validationFrame = pd.read_pickle("../../../Data/DataSplit/Validation.pkl")
validationFrame.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -1.601754 -0.408275 -0.788667 -1.142983 -1.512157 -0.353603 -0.338590
# 1  0.025378  0.418853  0.034701  4.251172 -0.396508  3.287433  1.986794
# 2 -0.697826  1.466843 -0.721390  3.081282 -0.023898  3.202064  1.800255
# 3  0.690207 -2.802670  0.039824 -0.452984  0.733203  1.993621  1.060869
# 4  1.113541 -4.343674  1.501242  2.608504  0.282633  0.814241  0.213915
#
#         PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0  0.146634 -0.643450  1.333976  ...           0            2            0
# 1  1.873284  0.665698 -0.663097  ...           6            2            0
# 2  3.991179  1.138871 -0.348235  ...           0            7            0
# 3 -0.541040 -1.755796  0.481612  ...           0            0            0
# 4 -1.158998 -1.689059 -1.494052  ...           0            2            0
#
#    FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0            1                1             4              8
# 1            0                0             0              8
# 2            0                0             0              7
# 3            1                0             3              4
# 4            0                0             0              2
#
#    CalculatedSecondQuality  Defect  OrderQuantity
# 0                        8      12            370
# 1                        8       8            160
# 2                        7      12            205
# 3                        4       6            185
# 4                        2      11            185
#
# [5 rows x 41 columns]

# %%
#Information of validationFrame is being printed
validationFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      25 non-null     float64
#  1   PC1                      25 non-null     float64
#  2   PC2                      25 non-null     float64
#  3   PC3                      25 non-null     float64
#  4   PC4                      25 non-null     float64
#  5   PC5                      25 non-null     float64
#  6   PC6                      25 non-null     float64
#  7   PC7                      25 non-null     float64
#  8   PC8                      25 non-null     float64
#  9   PC9                      25 non-null     float64
#  10  PC10                     25 non-null     float64
#  11  PC11                     25 non-null     float64
#  12  PC12                     25 non-null     float64
#  13  PC13                     25 non-null     float64
#  14  PC14                     25 non-null     float64
#  15  PC15                     25 non-null     float64
#  16  PC16                     25 non-null     float64
#  17  PC17                     25 non-null     float64
#  18  PC18                     25 non-null     float64
#  19  PC19                     25 non-null     float64
#  20  PC20                     25 non-null     float64
#  21  PC21                     25 non-null     float64
#  22  PC22                     25 non-null     float64
#  23  PrintErrorRate           25 non-null     float64
#  24  SewingErrorRate          25 non-null     float64
#  25  FabricStainRate          25 non-null     float64
#  26  FabricErrorRate          25 non-null     float64
#  27  EmbroideryErrorRate      25 non-null     float64
#  28  MeasureErrorRate         25 non-null     float64
#  29  SecondQualityRate        25 non-null     float64
#  30  DefectRate               25 non-null     float64
#  31  PrintError               25 non-null     int64
#  32  SewingError              25 non-null     int64
#  33  FabricStain              25 non-null     int64
#  34  FabricError              25 non-null     int64
#  35  EmbroideryError          25 non-null     int64
#  36  MeasureError             25 non-null     int64
#  37  SecondQuality            25 non-null     int64
#  38  CalculatedSecondQuality  25 non-null     int64
#  39  Defect                   25 non-null     int64
#  40  OrderQuantity            25 non-null     int64
# dtypes: float64(31), int64(10)
# memory usage: 8.1 KB

# %%
#Statistical information of validationFrame part to use is being printed
validationFrame.loc[:, : 'DefectRate'].describe()
# Out:
#              PC0        PC1        PC2        PC3        PC4        PC5  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean   -0.178009   0.841029  -0.330317   0.694910   0.526580   0.612656
# std     1.875163   2.388770   2.098771   2.001808   1.694058   2.025949
# min    -2.587016  -4.473841  -3.172407  -1.951797  -1.512157  -2.481010
# 25%    -1.285835   0.217390  -1.713168  -0.615858  -0.748153  -0.835252
# 50%    -0.600887   1.337435  -0.663736  -0.069064   0.073777   0.653674
# 75%     0.087226   1.916686   0.039824   2.234394   1.788728   1.707645
# max     5.128034   3.940754   7.384269   4.841975   5.556841   4.879057
#
#              PC6        PC7        PC8        PC9  ...       PC21       PC22  \
# count  25.000000  25.000000  25.000000  25.000000  ...  25.000000  25.000000
# mean    1.003164   0.237304  -0.251614  -0.075676  ...  -0.056123   0.055990
# std     2.104197   1.842426   1.217884   1.119167  ...   1.288558   0.676082
# min    -2.011895  -3.519059  -2.678456  -1.494052  ...  -2.051919  -1.644212
# 25%    -0.335407  -0.647871  -1.130517  -0.819009  ...  -0.831484  -0.383883
# 50%     0.574539   0.146634  -0.017278  -0.366633  ...  -0.181466  -0.112759
# 75%     1.986794   1.206313   0.653157   0.955768  ...   0.591302   0.639270
# max     5.052129   3.991179   2.202286   1.997094  ...   3.210872   1.135576
#
#        PrintErrorRate  SewingErrorRate  FabricStainRate  FabricErrorRate  \
# count       25.000000        25.000000        25.000000        25.000000
# mean         0.003628         0.017052         0.000371         0.004010
# std          0.008077         0.014952         0.001057         0.008141
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.005405         0.000000         0.000000
# 50%          0.000000         0.014563         0.000000         0.000000
# 75%          0.003546         0.020161         0.000000         0.003571
# max          0.033520         0.053892         0.004032         0.036290
#
#        EmbroideryErrorRate  MeasureErrorRate  SecondQualityRate  DefectRate
# count            25.000000         25.000000          25.000000   25.000000
# mean              0.000098          0.001959           0.027119    0.042068
# std               0.000491          0.005363           0.018203    0.022033
# min               0.000000          0.000000           0.004678    0.005587
# 25%               0.000000          0.000000           0.017007    0.028846
# 50%               0.000000          0.000000           0.020161    0.038672
# 75%               0.000000          0.000000           0.040541    0.054054
# max               0.002457          0.021739           0.074850    0.095808
#
# [8 rows x 31 columns]

# %%
#validationX is being created with input features of trainingFrame
validationX = validationFrame.loc[:, : 'PC22'].values
validationX.shape
# Out:
# (25, 23)

# %%
#validationY is being created with SecondQualityRate feature of validationFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
validationY = validationFrame['SecondQualityRate'].values.reshape(-1, 1) * 100
validationY.shape
# Out:
# (25, 1)

# %%
#CreateModel function that returns an ordinary Regression Artificial Neural Network Sequential Model is being defined
def CreateModel(inputSize, outputSize):
    model = Sequential()

    model.add(Dense(512, kernel_initializer = 'normal', input_dim = inputSize, activation = 'relu'))
    model.add(Dense(512, kernel_initializer = 'normal', activation = 'relu'))
    model.add(Dense(512, kernel_initializer = 'normal', activation = 'relu'))
    model.add(Dense(512, kernel_initializer = 'normal', activation = 'relu'))

    model.add(Dense(outputSize, kernel_initializer = 'normal', activation = 'linear'))
    
    return model

# %%
#A customized Callback class that inherits the tensorflow.keras.callbacks.Callback class is being defined

#This customized Callback class will perform the necessary checks at the end of each epoch
#and will update the weights of the bestModel with the weights  and metrics of the model
#This Callback also save the best model

#In this way, predictions and test operations can be repeated with the model with the lowest loss value
class KeepBest(Callback):
    def __init__(self, bestModel):
        self.bestLoss = None
        self.bestValLoss = None
        self.bestMAE = None
        self.bestValMAE = None
        self.bestModel = bestModel
        
    def on_epoch_end(self, epoch, logs=None):
        if self.bestValLoss is None or self.bestValLoss > logs['val_loss']:
            self.bestLoss = logs['loss']
            self.bestValLoss = logs['val_loss']
            self.bestMAE = logs['mean_absolute_error']
            self.bestValMAE = logs['val_mean_absolute_error']
            self.bestModel.set_weights(model.get_weights())
            model.save('../../Model/SingleOutput/NeuralNetwork/ANN.h5')

# %%
#A model to use for the KeepBest object is being created
bestModel = CreateModel(trainingX.shape[1], trainingY.shape[1])
bestModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               12288
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 800,769
# Trainable params: 800,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
#A KeepBest object is being created
KeepBestObject = KeepBest(bestModel)

# %%
#A model is being created for training
model = CreateModel(trainingX.shape[1], trainingY.shape[1])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 512)               12288
#
#  dense_6 (Dense)             (None, 512)               262656
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 800,769
# Trainable params: 800,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model is being compiled with Adam optimizer and Mean Squared Error loss function
model.compile(optimizer = Adam(), loss = MSE, metrics=[MAE])

# %%
#model is being trained
model.fit(trainingX, trainingY,
          validation_data = (validationX, validationY),
          epochs = EPOCH_NUMBER, batch_size = BATCH_SIZE,
          callbacks = [KeepBestObject])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 270ms/step - loss: 6.0628 - mean_absolute_error: 1.8198 - val_loss: 5.2648 - val_mean_absolute_error: 1.8736
# Epoch 2/50
# 3/3 [==============================] - 0s 136ms/step - loss: 3.9455 - mean_absolute_error: 1.6278 - val_loss: 3.7021 - val_mean_absolute_error: 1.4476
# Epoch 3/50
# 3/3 [==============================] - 0s 22ms/step - loss: 2.8537 - mean_absolute_error: 1.1403 - val_loss: 4.5220 - val_mean_absolute_error: 1.6001
# Epoch 4/50
# 3/3 [==============================] - 0s 171ms/step - loss: 2.8928 - mean_absolute_error: 1.1523 - val_loss: 3.5976 - val_mean_absolute_error: 1.4442
# Epoch 5/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.9018 - mean_absolute_error: 1.0498 - val_loss: 4.6381 - val_mean_absolute_error: 1.6344
# Epoch 6/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9513 - mean_absolute_error: 1.1428 - val_loss: 3.9181 - val_mean_absolute_error: 1.4968
# Epoch 7/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.5035 - mean_absolute_error: 0.9131 - val_loss: 3.8640 - val_mean_absolute_error: 1.4996
# Epoch 8/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.5653 - mean_absolute_error: 0.9015 - val_loss: 3.9320 - val_mean_absolute_error: 1.5083
# Epoch 9/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3461 - mean_absolute_error: 0.8518 - val_loss: 4.5834 - val_mean_absolute_error: 1.6399
# Epoch 10/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.4890 - mean_absolute_error: 0.9066 - val_loss: 4.5994 - val_mean_absolute_error: 1.6588
# Epoch 11/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1826 - mean_absolute_error: 0.7774 - val_loss: 4.1942 - val_mean_absolute_error: 1.5911
# Epoch 12/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2717 - mean_absolute_error: 0.8143 - val_loss: 4.2412 - val_mean_absolute_error: 1.6158
# Epoch 13/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0232 - mean_absolute_error: 0.7276 - val_loss: 4.7566 - val_mean_absolute_error: 1.7325
# Epoch 14/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0118 - mean_absolute_error: 0.7445 - val_loss: 4.8281 - val_mean_absolute_error: 1.7505
# Epoch 15/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9600 - mean_absolute_error: 0.7111 - val_loss: 4.2021 - val_mean_absolute_error: 1.6214
# Epoch 16/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8753 - mean_absolute_error: 0.6661 - val_loss: 4.0814 - val_mean_absolute_error: 1.5856
# Epoch 17/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8387 - mean_absolute_error: 0.6542 - val_loss: 4.2664 - val_mean_absolute_error: 1.6456
# Epoch 18/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8042 - mean_absolute_error: 0.6266 - val_loss: 4.4447 - val_mean_absolute_error: 1.6871
# Epoch 19/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.8093 - mean_absolute_error: 0.6236 - val_loss: 4.3810 - val_mean_absolute_error: 1.6732
# Epoch 20/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7252 - mean_absolute_error: 0.5752 - val_loss: 4.4759 - val_mean_absolute_error: 1.6900
# Epoch 21/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7153 - mean_absolute_error: 0.5708 - val_loss: 4.7432 - val_mean_absolute_error: 1.7411
# Epoch 22/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7159 - mean_absolute_error: 0.5569 - val_loss: 4.8224 - val_mean_absolute_error: 1.7688
# Epoch 23/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6632 - mean_absolute_error: 0.5445 - val_loss: 4.4477 - val_mean_absolute_error: 1.7003
# Epoch 24/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6862 - mean_absolute_error: 0.5520 - val_loss: 4.4004 - val_mean_absolute_error: 1.6975
# Epoch 25/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6778 - mean_absolute_error: 0.5456 - val_loss: 4.6487 - val_mean_absolute_error: 1.7538
# Epoch 26/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6529 - mean_absolute_error: 0.5297 - val_loss: 4.9929 - val_mean_absolute_error: 1.8108
# Epoch 27/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6785 - mean_absolute_error: 0.5264 - val_loss: 4.9535 - val_mean_absolute_error: 1.7798
# Epoch 28/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6940 - mean_absolute_error: 0.5179 - val_loss: 4.9266 - val_mean_absolute_error: 1.7625
# Epoch 29/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6450 - mean_absolute_error: 0.5100 - val_loss: 5.3125 - val_mean_absolute_error: 1.8349
# Epoch 30/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6895 - mean_absolute_error: 0.5639 - val_loss: 4.7276 - val_mean_absolute_error: 1.7353
# Epoch 31/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6542 - mean_absolute_error: 0.5178 - val_loss: 4.2373 - val_mean_absolute_error: 1.6242
# Epoch 32/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6420 - mean_absolute_error: 0.5341 - val_loss: 4.4593 - val_mean_absolute_error: 1.6869
# Epoch 33/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6268 - mean_absolute_error: 0.5185 - val_loss: 4.9553 - val_mean_absolute_error: 1.7892
# Epoch 34/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6178 - mean_absolute_error: 0.5039 - val_loss: 4.9950 - val_mean_absolute_error: 1.7618
# Epoch 35/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6208 - mean_absolute_error: 0.4773 - val_loss: 5.1957 - val_mean_absolute_error: 1.7911
# Epoch 36/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5933 - mean_absolute_error: 0.4643 - val_loss: 5.3070 - val_mean_absolute_error: 1.8162
# Epoch 37/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5639 - mean_absolute_error: 0.4588 - val_loss: 4.8316 - val_mean_absolute_error: 1.7520
# Epoch 38/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5642 - mean_absolute_error: 0.4412 - val_loss: 4.5166 - val_mean_absolute_error: 1.6887
# Epoch 39/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5933 - mean_absolute_error: 0.4633 - val_loss: 4.3500 - val_mean_absolute_error: 1.6534
# Epoch 40/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5960 - mean_absolute_error: 0.4460 - val_loss: 4.7948 - val_mean_absolute_error: 1.7487
# Epoch 41/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5716 - mean_absolute_error: 0.4604 - val_loss: 4.9047 - val_mean_absolute_error: 1.7541
# Epoch 42/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5560 - mean_absolute_error: 0.4195 - val_loss: 4.9516 - val_mean_absolute_error: 1.7483
# Epoch 43/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5686 - mean_absolute_error: 0.4439 - val_loss: 5.4823 - val_mean_absolute_error: 1.8334
# Epoch 44/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6248 - mean_absolute_error: 0.4759 - val_loss: 5.6193 - val_mean_absolute_error: 1.8566
# Epoch 45/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5712 - mean_absolute_error: 0.4559 - val_loss: 4.9556 - val_mean_absolute_error: 1.7779
# Epoch 46/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5775 - mean_absolute_error: 0.4642 - val_loss: 4.7303 - val_mean_absolute_error: 1.7223
# Epoch 47/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5709 - mean_absolute_error: 0.4633 - val_loss: 4.8297 - val_mean_absolute_error: 1.7420
# Epoch 48/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5468 - mean_absolute_error: 0.4460 - val_loss: 5.0197 - val_mean_absolute_error: 1.7854
# Epoch 49/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5121 - mean_absolute_error: 0.4097 - val_loss: 4.9274 - val_mean_absolute_error: 1.7617
# Epoch 50/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5474 - mean_absolute_error: 0.4593 - val_loss: 4.9158 - val_mean_absolute_error: 1.7608

# %%
#A DataFrame based on model.history data is being created named as lossFrame for chart
lossFrame = pd.DataFrame(model.history.history)
lossFrame.head()
# Out:
#        loss  mean_absolute_error  val_loss  val_mean_absolute_error
# 0  6.062755             1.819774  5.264761                 1.873645
# 1  3.945459             1.627810  3.702060                 1.447551
# 2  2.853720             1.140258  4.521966                 1.600091
# 3  2.892829             1.152272  3.597558                 1.444175
# 4  1.901807             1.049839  4.638107                 1.634431

# %%
#A Loss chart based on lossFrame data is being plotted
lossFrame[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot: >

# %%
#A MAE chart based on lossFrame data is being plotted
lossFrame[['mean_absolute_error', 'val_mean_absolute_error']].plot()
# Out:
# <AxesSubplot: >

# %%
#resultFrame based on best model results is being created
resultDict = {'Model' : MODEL_NAME,
              'Data' : 'Training',
              'MeanAbsoluteError' : [KeepBestObject.bestMAE], 
              'MeanSquaredError' : [KeepBestObject.bestLoss]}
resultDict['SqrtMeanSquaredError'] = np.sqrt(resultDict['MeanSquaredError'])
resultFrame = pd.DataFrame(resultDict)
resultFrame
# Out:
#   Model      Data  MeanAbsoluteError  MeanSquaredError  SqrtMeanSquaredError
# 0   ANN  Training           1.152272          2.892829              1.700832

# %%
#resultFrame based on best model results is being created
resultDict = {'Model' : MODEL_NAME,
              'Data' : 'Validation',
              'MeanAbsoluteError' : [KeepBestObject.bestValMAE], 
              'MeanSquaredError' : [KeepBestObject.bestValLoss]}
resultDict['SqrtMeanSquaredError'] = np.sqrt(resultDict['MeanSquaredError'])
resultFrame = pd.concat([resultFrame, pd.DataFrame(resultDict)]).reset_index(drop = True)
resultFrame
# Out:
#   Model        Data  MeanAbsoluteError  MeanSquaredError  SqrtMeanSquaredError
# 0   ANN    Training           1.152272          2.892829              1.700832
# 1   ANN  Validation           1.444175          3.597558              1.896723

# %%
#Predictions are made on the test data with the model with the lowest loss value
predictions = KeepBestObject.bestModel.predict(validationX)
# Out:
# 1/1 [==============================] - 0s 109ms/step

# %%
#Chart to show the closeness of the SecondQualityRate predictions to the true values is being plaotted
plt.figure(figsize = (12, 6))
plt.title('SecondQualityRate')
plt.scatter(validationY, predictions)
plt.plot(validationY, validationY, 'r')
plt.legend(['Predictions', 'LineOfRealValues'])

# %%
#testFrame is being created by reading a pkl file
testFrame = pd.read_pickle("../../../Data/DataSplit/Test.pkl")
testFrame.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -2.013910  1.995143 -1.926260 -1.974847 -0.470229 -0.920815  5.463404
# 1  0.081436  0.312799 -0.204645  4.329446 -0.406149  3.267323  2.083090
# 2 -0.275271  3.378519  6.180660 -3.070387 -1.256094  2.695950 -1.440188
# 3  0.943398 -4.813578  0.824529  0.275050  0.786546  0.370814  0.870501
# 4 -0.379232  3.409618 -3.162239  2.686746  3.859326  0.532266 -1.527445
#
#         PC7       PC8       PC9  ...  PrintError  SewingError  FabricStain  \
# 0 -2.759364  2.244603 -0.119326  ...           2           15            5
# 1  1.907919  0.579843 -0.524113  ...           0            3            0
# 2 -1.783384  1.923091 -3.025943  ...          93           26            2
# 3  0.563257 -2.901741 -3.165466  ...           0            3            1
# 4 -1.047937 -1.601517 -0.551928  ...           0            0            0
#
#    FabricError  EmbroideryError  MeasureError  SecondQuality  \
# 0            2                0             2             25
# 1            1                0             0              4
# 2            3                0             0            123
# 3            0                0             0              4
# 4            0                5             0              5
#
#    CalculatedSecondQuality  Defect  OrderQuantity
# 0                       26      32            420
# 1                        4       5            150
# 2                      124     143           4395
# 3                        4       5            200
# 4                        5       7            170
#
# [5 rows x 41 columns]

# %%
#Information of testFrame is being printed
testFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PC0                      25 non-null     float64
#  1   PC1                      25 non-null     float64
#  2   PC2                      25 non-null     float64
#  3   PC3                      25 non-null     float64
#  4   PC4                      25 non-null     float64
#  5   PC5                      25 non-null     float64
#  6   PC6                      25 non-null     float64
#  7   PC7                      25 non-null     float64
#  8   PC8                      25 non-null     float64
#  9   PC9                      25 non-null     float64
#  10  PC10                     25 non-null     float64
#  11  PC11                     25 non-null     float64
#  12  PC12                     25 non-null     float64
#  13  PC13                     25 non-null     float64
#  14  PC14                     25 non-null     float64
#  15  PC15                     25 non-null     float64
#  16  PC16                     25 non-null     float64
#  17  PC17                     25 non-null     float64
#  18  PC18                     25 non-null     float64
#  19  PC19                     25 non-null     float64
#  20  PC20                     25 non-null     float64
#  21  PC21                     25 non-null     float64
#  22  PC22                     25 non-null     float64
#  23  PrintErrorRate           25 non-null     float64
#  24  SewingErrorRate          25 non-null     float64
#  25  FabricStainRate          25 non-null     float64
#  26  FabricErrorRate          25 non-null     float64
#  27  EmbroideryErrorRate      25 non-null     float64
#  28  MeasureErrorRate         25 non-null     float64
#  29  SecondQualityRate        25 non-null     float64
#  30  DefectRate               25 non-null     float64
#  31  PrintError               25 non-null     int64
#  32  SewingError              25 non-null     int64
#  33  FabricStain              25 non-null     int64
#  34  FabricError              25 non-null     int64
#  35  EmbroideryError          25 non-null     int64
#  36  MeasureError             25 non-null     int64
#  37  SecondQuality            25 non-null     int64
#  38  CalculatedSecondQuality  25 non-null     int64
#  39  Defect                   25 non-null     int64
#  40  OrderQuantity            25 non-null     int64
# dtypes: float64(31), int64(10)
# memory usage: 8.1 KB

# %%
#Statistical information of testFrame part to use is being printed
testFrame.loc[:, : 'DefectRate'].describe()
# Out:
#              PC0        PC1        PC2        PC3        PC4        PC5  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.013024   0.454578  -0.202597   0.279146  -0.191783   0.205207
# std     2.863422   2.356419   2.651003   2.553474   1.846505   1.743946
# min    -2.551436  -4.813578  -5.463644  -4.955933  -2.546559  -3.651559
# 25%    -0.758804  -1.143406  -1.556957  -1.558052  -1.478593  -0.849267
# 50%    -0.379232   0.395125  -0.315427   0.275050  -0.512525   0.087782
# 75%     0.085605   1.995143   0.415892   2.469710   0.351512   1.472206
# max    12.352104   3.858221   7.682068   4.371193   5.226237   3.279513
#
#              PC6        PC7        PC8        PC9  ...       PC21       PC22  \
# count  25.000000  25.000000  25.000000  25.000000  ...  25.000000  25.000000
# mean    0.494423  -0.527151   0.060211  -0.557505  ...   0.567818   0.239675
# std     2.241005   1.566362   1.592350   1.674245  ...   1.379990   0.852453
# min    -3.551327  -2.782388  -2.901741  -5.528565  ...  -1.965344  -2.033394
# 25%    -0.887723  -1.783384  -0.906136  -0.831912  ...  -0.529781  -0.181202
# 50%     0.200355  -0.501114  -0.104364  -0.430639  ...   0.848378   0.480764
# 75%     0.870501   0.563257   0.579843   0.518843  ...   1.588861   0.707311
# max     5.463404   2.711760   3.024043   1.731993  ...   3.393513   2.035233
#
#        PrintErrorRate  SewingErrorRate  FabricStainRate  FabricErrorRate  \
# count       25.000000        25.000000        25.000000        25.000000
# mean         0.003294         0.015150         0.000676         0.003143
# std          0.005886         0.015264         0.002298         0.003419
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.004693         0.000000         0.000000
# 50%          0.000000         0.009050         0.000000         0.003546
# 75%          0.004255         0.018182         0.000000         0.004545
# max          0.020480         0.065657         0.010799         0.013158
#
#        EmbroideryErrorRate  MeasureErrorRate  SecondQualityRate  DefectRate
# count            25.000000         25.000000          25.000000   25.000000
# mean              0.001066          0.000173           0.023501    0.041856
# std               0.005205          0.000864           0.016756    0.020805
# min               0.000000          0.000000           0.004032    0.016129
# 25%               0.000000          0.000000           0.011312    0.029144
# 50%               0.000000          0.000000           0.020590    0.036458
# 75%               0.000000          0.000000           0.027273    0.048193
# max               0.026042          0.004320           0.070707    0.101010
#
# [8 rows x 31 columns]

# %%
#testX is being created with input features of testFrame
testX = testFrame.loc[:, : 'PC22'].values
testX.shape
# Out:
# (25, 23)

# %%
#testY is being created with SecondQualityRate feature of testFrame
#Rates in the 0-1 range are being multiplied by 100 to get them into the 0-100 range
testY = testFrame['SecondQualityRate'].values * 100
testY.shape
# Out:
# (25,)

# %%
#Predictions are made on the test data with the model with the lowest loss value
predictions = KeepBestObject.bestModel.predict(testX)
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
#Shape of predictions is being printed
predictions.shape
# Out:
# (25, 1)

# %%
#resultFrame based on predictions and real values is being created
resultDict = {'Model' : MODEL_NAME,
              'Data' : 'Test',
              'MeanAbsoluteError' : [mean_absolute_error(predictions, testY)], 
              'MeanSquaredError' : [mean_squared_error(predictions, testY)]}
resultDict['SqrtMeanSquaredError'] = np.sqrt(resultDict['MeanSquaredError'])
resultFrame = pd.concat([resultFrame, pd.DataFrame(resultDict)]).reset_index(drop = True)
resultFrame
# Out:
#   Model        Data  MeanAbsoluteError  MeanSquaredError  SqrtMeanSquaredError
# 0   ANN    Training           1.152272          2.892829              1.700832
# 1   ANN  Validation           1.444175          3.597558              1.896723
# 2   ANN        Test           1.012936          1.811028              1.345745

# %%
#Chart to show the closeness of the SecondQualityRate predictions to the true values is being plaotted
plt.figure(figsize = (12, 6))
plt.title('SecondQualityRate')
plt.scatter(testY, predictions)
plt.plot(testY, testY, 'r')
plt.legend(['Predictions', 'LineOfRealValues'])

# %%
#resultFrame is being saved as pkl files
resultFrame.to_pickle('../../Model/SingleOutput/NeuralNetwork/ResultFrame.pkl')
